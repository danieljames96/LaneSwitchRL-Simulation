# %%
import os
import sys
import json
from datetime import datetime

import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
# Add the `src` folder to the Python path
sys.path.append(os.path.join(os.path.abspath('..'), 'src'))
import environment_gym_sh as env_gym_sh

# Load the TensorBoard extension
# %reload_ext tensorboard

# %% [markdown]
# ## Change State Representation

# %% [markdown]
# State = [distance index, current lane, clearance rates of 5 lanes, clearance rate index of 5 lanes, clearance rate difference to left lane, clearance rate difference to right lane, fastest lane, clerance rate difference to fastest lane]

# %% [markdown]
# ### Train PPO Model 1

# %%
# Initialize and vectorize the environment
env = env_gym_sh.TrafficEnvironment()
check_env(env, warn=True)
env.reset()
eval_env = Monitor(env_gym_sh.TrafficEnvironment())

# Set up log directory
log_dir = "./logs/ppo_sh_baseline_model/"
os.makedirs(log_dir + "best_model/", exist_ok=True)
os.makedirs(log_dir + "final_model/", exist_ok=True)

# Define the PPO model with MlpPolicy (a policy network that works well with continuous environments)
model = PPO(policy = "MlpPolicy",
            device = "cpu",    # PPO is meant to be run primarily on the CPU 
            env = env, 
            verbose = 1,
            tensorboard_log = log_dir
           )

# Set up evaluation callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=log_dir + "best_model/",
    log_path=log_dir + "results/",
    eval_freq=1000,  # Evaluate the model every 1000 steps
    deterministic=True,
    render=False
)

# Train the PPO model
total_timesteps = 50000
model.learn(total_timesteps=total_timesteps, callback=eval_callback)

# Save the final model
final_model_path = log_dir + "final_model"
model.save(final_model_path)
print(f"Final model saved to {final_model_path}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/ppo_gs_baseline_model/PPO_1
# Eval num_timesteps=1000, episode_reward=-9801.00 +/- 20672.41
# Episode length: 939.20 +/- 1371.54
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 939      |
# |    mean_reward     | -9.8e+03 |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=767.00 +/- 1031.68
# Episode length: 247.20 +/- 74.26
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 247      |
# |    mean_reward     | 767      |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# New best mean reward!
# -----------------------------
# | time/              |      |
# |    fps             | 231  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=-1169.00 +/- 5713.42
# Episode length: 515.40 +/- 572.30
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 515         |
# |    mean_reward          | -1.17e+03   |
# | time/                   |             |
# |    total_timesteps      | 3000        |
# | train/                  |             |
# |    approx_kl            | 0.017193627 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 3.4e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 3.92e+04    |
# -----------------------------------------
# Eval num_timesteps=4000, episode_reward=-5694.00 +/- 11808.69
# Episode length: 969.40 +/- 1180.87
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 969       |
# |    mean_reward     | -5.69e+03 |
# | time/              |           |
# |    total_timesteps | 4000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 790       |
# |    ep_rew_mean     | -6.42e+03 |
# | time/              |           |
# |    fps             | 190       |
# |    iterations      | 2         |
# |    time_elapsed    | 21        |
# |    total_timesteps | 4096      |
# ----------------------------------
# Eval num_timesteps=5000, episode_reward=-3330.00 +/- 5350.64
# Episode length: 733.00 +/- 535.06
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 733         |
# |    mean_reward          | -3.33e+03   |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.009898119 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.000813    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 2.19e+04    |
# -----------------------------------------
# Eval num_timesteps=6000, episode_reward=178.00 +/- 1154.53
# Episode length: 382.20 +/- 115.45
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 382      |
# |    mean_reward     | 178      |
# | time/              |          |
# |    total_timesteps | 6000     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 708       |
# |    ep_rew_mean     | -5.23e+03 |
# | time/              |           |
# |    fps             | 192       |
# |    iterations      | 3         |
# |    time_elapsed    | 31        |
# |    total_timesteps | 6144      |
# ----------------------------------
# Eval num_timesteps=7000, episode_reward=-6708.00 +/- 12786.72
# Episode length: 1070.80 +/- 1278.67
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.07e+03    |
# |    mean_reward          | -6.71e+03   |
# | time/                   |             |
# |    total_timesteps      | 7000        |
# | train/                  |             |
# |    approx_kl            | 0.011010672 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 2.43e+04    |
# -----------------------------------------
# Eval num_timesteps=8000, episode_reward=-9350.00 +/- 9913.14
# Episode length: 1335.00 +/- 991.31
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.34e+03  |
# |    mean_reward     | -9.35e+03 |
# | time/              |           |
# |    total_timesteps | 8000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 708       |
# |    ep_rew_mean     | -5.23e+03 |
# | time/              |           |
# |    fps             | 167       |
# |    iterations      | 4         |
# |    time_elapsed    | 48        |
# |    total_timesteps | 8192      |
# ----------------------------------
# Eval num_timesteps=9000, episode_reward=-5824.00 +/- 10013.23
# Episode length: 982.40 +/- 1001.32
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 982         |
# |    mean_reward          | -5.82e+03   |
# | time/                   |             |
# |    total_timesteps      | 9000        |
# | train/                  |             |
# |    approx_kl            | 0.019709665 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | -0.000556   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+04     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 3.51e+04    |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=-5548.00 +/- 7323.42
# Episode length: 954.80 +/- 732.34
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 955       |
# |    mean_reward     | -5.55e+03 |
# | time/              |           |
# |    total_timesteps | 10000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 955       |
# |    ep_rew_mean     | -8.11e+03 |
# | time/              |           |
# |    fps             | 162       |
# |    iterations      | 5         |
# |    time_elapsed    | 63        |
# |    total_timesteps | 10240     |
# ----------------------------------
# Eval num_timesteps=11000, episode_reward=-3620.00 +/- 9901.85
# Episode length: 762.00 +/- 990.18
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 762        |
# |    mean_reward          | -3.62e+03  |
# | time/                   |            |
# |    total_timesteps      | 11000      |
# | train/                  |            |
# |    approx_kl            | 0.00690313 |
# |    clip_fraction        | 0.0124     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.853     |
# |    explained_variance   | 0.0673     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05e+04   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00401   |
# |    value_loss           | 2.19e+04   |
# ----------------------------------------
# Eval num_timesteps=12000, episode_reward=-4164.00 +/- 9023.29
# Episode length: 816.40 +/- 902.33
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 816       |
# |    mean_reward     | -4.16e+03 |
# | time/              |           |
# |    total_timesteps | 12000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 982       |
# |    ep_rew_mean     | -8.27e+03 |
# | time/              |           |
# |    fps             | 162       |
# |    iterations      | 6         |
# |    time_elapsed    | 75        |
# |    total_timesteps | 12288     |
# ----------------------------------
# Eval num_timesteps=13000, episode_reward=-286.00 +/- 1662.92
# Episode length: 428.60 +/- 166.29
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 429          |
# |    mean_reward          | -286         |
# | time/                   |              |
# |    total_timesteps      | 13000        |
# | train/                  |              |
# |    approx_kl            | 0.0073099304 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.767       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.96e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 2.17e+04     |
# ------------------------------------------
# Eval num_timesteps=14000, episode_reward=-886.00 +/- 3319.02
# Episode length: 488.60 +/- 331.90
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 489      |
# |    mean_reward     | -886     |
# | time/              |          |
# |    total_timesteps | 14000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 842       |
# |    ep_rew_mean     | -6.36e+03 |
# | time/              |           |
# |    fps             | 168       |
# |    iterations      | 7         |
# |    time_elapsed    | 85        |
# |    total_timesteps | 14336     |
# ----------------------------------
# Eval num_timesteps=15000, episode_reward=-9030.00 +/- 11208.13
# Episode length: 1303.00 +/- 1120.81
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.3e+03     |
# |    mean_reward          | -9.03e+03   |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.007733698 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.1e+03     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 1.37e+04    |
# -----------------------------------------
# Eval num_timesteps=16000, episode_reward=-2154.00 +/- 3400.00
# Episode length: 615.40 +/- 340.00
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 615       |
# |    mean_reward     | -2.15e+03 |
# | time/              |           |
# |    total_timesteps | 16000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 742       |
# |    ep_rew_mean     | -5.05e+03 |
# | time/              |           |
# |    fps             | 164       |
# |    iterations      | 8         |
# |    time_elapsed    | 99        |
# |    total_timesteps | 16384     |
# ----------------------------------
# Eval num_timesteps=17000, episode_reward=-9192.00 +/- 10349.14
# Episode length: 1319.20 +/- 1034.91
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.32e+03    |
# |    mean_reward          | -9.19e+03   |
# | time/                   |             |
# |    total_timesteps      | 17000       |
# | train/                  |             |
# |    approx_kl            | 0.003999558 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 1.61e+04    |
# -----------------------------------------
# Eval num_timesteps=18000, episode_reward=-4478.00 +/- 7702.46
# Episode length: 847.80 +/- 770.25
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 848       |
# |    mean_reward     | -4.48e+03 |
# | time/              |           |
# |    total_timesteps | 18000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 729       |
# |    ep_rew_mean     | -4.81e+03 |
# | time/              |           |
# |    fps             | 160       |
# |    iterations      | 9         |
# |    time_elapsed    | 115       |
# |    total_timesteps | 18432     |
# ----------------------------------
# Eval num_timesteps=19000, episode_reward=-3090.00 +/- 8112.93
# Episode length: 709.00 +/- 811.29
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 709          |
# |    mean_reward          | -3.09e+03    |
# | time/                   |              |
# |    total_timesteps      | 19000        |
# | train/                  |              |
# |    approx_kl            | 0.0012406855 |
# |    clip_fraction        | 0.00566      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.699       |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.91e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 1.74e+04     |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=-7484.00 +/- 8144.02
# Episode length: 1148.40 +/- 814.40
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.15e+03  |
# |    mean_reward     | -7.48e+03 |
# | time/              |           |
# |    total_timesteps | 20000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 701       |
# |    ep_rew_mean     | -4.44e+03 |
# | time/              |           |
# |    fps             | 158       |
# |    iterations      | 10        |
# |    time_elapsed    | 129       |
# |    total_timesteps | 20480     |
# ----------------------------------
# Eval num_timesteps=21000, episode_reward=-17428.00 +/- 16416.13
# Episode length: 2142.80 +/- 1641.61
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2.14e+03     |
# |    mean_reward          | -1.74e+04    |
# | time/                   |              |
# |    total_timesteps      | 21000        |
# | train/                  |              |
# |    approx_kl            | 0.0108418865 |
# |    clip_fraction        | 0.0804       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.58e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00727     |
# |    value_loss           | 1.81e+04     |
# ------------------------------------------
# Eval num_timesteps=22000, episode_reward=-7404.00 +/- 10381.83
# Episode length: 1140.40 +/- 1038.18
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.14e+03 |
# |    mean_reward     | -7.4e+03 |
# | time/              |          |
# |    total_timesteps | 22000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 784       |
# |    ep_rew_mean     | -5.33e+03 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 11        |
# |    time_elapsed    | 150       |
# |    total_timesteps | 22528     |
# ----------------------------------
# Eval num_timesteps=23000, episode_reward=-8328.00 +/- 10154.30
# Episode length: 1232.80 +/- 1015.43
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.23e+03     |
# |    mean_reward          | -8.33e+03    |
# | time/                   |              |
# |    total_timesteps      | 23000        |
# | train/                  |              |
# |    approx_kl            | 0.0052529895 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.32e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 2e+04        |
# ------------------------------------------
# Eval num_timesteps=24000, episode_reward=-600.00 +/- 4716.67
# Episode length: 460.00 +/- 471.67
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 460      |
# |    mean_reward     | -600     |
# | time/              |          |
# |    total_timesteps | 24000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 842       |
# |    ep_rew_mean     | -5.92e+03 |
# | time/              |           |
# |    fps             | 150       |
# |    iterations      | 12        |
# |    time_elapsed    | 163       |
# |    total_timesteps | 24576     |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=-4620.00 +/- 5432.84
# Episode length: 862.00 +/- 543.28
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 862          |
# |    mean_reward          | -4.62e+03    |
# | time/                   |              |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 0.0025186073 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.352        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.71e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 2.08e+04     |
# ------------------------------------------
# Eval num_timesteps=26000, episode_reward=-8976.00 +/- 8834.67
# Episode length: 1297.60 +/- 883.47
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.3e+03   |
# |    mean_reward     | -8.98e+03 |
# | time/              |           |
# |    total_timesteps | 26000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 806       |
# |    ep_rew_mean     | -5.41e+03 |
# | time/              |           |
# |    fps             | 148       |
# |    iterations      | 13        |
# |    time_elapsed    | 179       |
# |    total_timesteps | 26624     |
# ----------------------------------
# Eval num_timesteps=27000, episode_reward=-2904.00 +/- 4870.53
# Episode length: 690.40 +/- 487.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 690          |
# |    mean_reward          | -2.9e+03     |
# | time/                   |              |
# |    total_timesteps      | 27000        |
# | train/                  |              |
# |    approx_kl            | 0.0024067448 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.346       |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+04      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 1.74e+04     |
# ------------------------------------------
# Eval num_timesteps=28000, episode_reward=-9584.00 +/- 12128.91
# Episode length: 1358.40 +/- 1212.89
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.36e+03  |
# |    mean_reward     | -9.58e+03 |
# | time/              |           |
# |    total_timesteps | 28000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | -5.3e+03 |
# | time/              |          |
# |    fps             | 147      |
# |    iterations      | 14       |
# |    time_elapsed    | 193      |
# |    total_timesteps | 28672    |
# ---------------------------------
# Eval num_timesteps=29000, episode_reward=-15202.00 +/- 7987.39
# Episode length: 1920.20 +/- 798.74
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.92e+03    |
# |    mean_reward          | -1.52e+04   |
# | time/                   |             |
# |    total_timesteps      | 29000       |
# | train/                  |             |
# |    approx_kl            | 0.001990301 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.47e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 1.16e+04    |
# -----------------------------------------
# Eval num_timesteps=30000, episode_reward=-10148.00 +/- 8547.46
# Episode length: 1414.80 +/- 854.75
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.41e+03  |
# |    mean_reward     | -1.01e+04 |
# | time/              |           |
# |    total_timesteps | 30000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | -5.3e+03 |
# | time/              |          |
# |    fps             | 142      |
# |    iterations      | 15       |
# |    time_elapsed    | 215      |
# |    total_timesteps | 30720    |
# ---------------------------------
# Eval num_timesteps=31000, episode_reward=-4350.00 +/- 8725.03
# Episode length: 835.00 +/- 872.50
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 835         |
# |    mean_reward          | -4.35e+03   |
# | time/                   |             |
# |    total_timesteps      | 31000       |
# | train/                  |             |
# |    approx_kl            | 0.004048247 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | -1.01e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00973    |
# |    value_loss           | 2.21e+04    |
# -----------------------------------------
# Eval num_timesteps=32000, episode_reward=956.00 +/- 783.67
# Episode length: 304.40 +/- 78.37
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 304      |
# |    mean_reward     | 956      |
# | time/              |          |
# |    total_timesteps | 32000    |
# ---------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 883       |
# |    ep_rew_mean     | -6.11e+03 |
# | time/              |           |
# |    fps             | 144       |
# |    iterations      | 16        |
# |    time_elapsed    | 226       |
# |    total_timesteps | 32768     |
# ----------------------------------
# Eval num_timesteps=33000, episode_reward=-2492.00 +/- 6885.89
# Episode length: 649.20 +/- 688.59
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 649          |
# |    mean_reward          | -2.49e+03    |
# | time/                   |              |
# |    total_timesteps      | 33000        |
# | train/                  |              |
# |    approx_kl            | 0.0019319496 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | 0.485        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.23e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 1.72e+04     |
# ------------------------------------------
# Eval num_timesteps=34000, episode_reward=-5728.00 +/- 13100.09
# Episode length: 972.80 +/- 1310.01
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 973       |
# |    mean_reward     | -5.73e+03 |
# | time/              |           |
# |    total_timesteps | 34000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 864       |
# |    ep_rew_mean     | -5.88e+03 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 17        |
# |    time_elapsed    | 239       |
# |    total_timesteps | 34816     |
# ----------------------------------
# Eval num_timesteps=35000, episode_reward=-13144.00 +/- 16475.22
# Episode length: 1714.40 +/- 1647.52
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.71e+03     |
# |    mean_reward          | -1.31e+04    |
# | time/                   |              |
# |    total_timesteps      | 35000        |
# | train/                  |              |
# |    approx_kl            | 0.0013094771 |
# |    clip_fraction        | 0.00962      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.214       |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 1.97e+04     |
# ------------------------------------------
# Eval num_timesteps=36000, episode_reward=-13666.00 +/- 11494.79
# Episode length: 1766.60 +/- 1149.48
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.77e+03  |
# |    mean_reward     | -1.37e+04 |
# | time/              |           |
# |    total_timesteps | 36000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 865       |
# |    ep_rew_mean     | -5.79e+03 |
# | time/              |           |
# |    fps             | 140       |
# |    iterations      | 18        |
# |    time_elapsed    | 261       |
# |    total_timesteps | 36864     |
# ----------------------------------
# Eval num_timesteps=37000, episode_reward=-9026.00 +/- 18493.61
# Episode length: 1302.60 +/- 1849.36
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.3e+03       |
# |    mean_reward          | -9.03e+03     |
# | time/                   |               |
# |    total_timesteps      | 37000         |
# | train/                  |               |
# |    approx_kl            | 9.7303244e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.15         |
# |    explained_variance   | 0.461         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.81e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000453     |
# |    value_loss           | 1.18e+04      |
# -------------------------------------------
# Eval num_timesteps=38000, episode_reward=58.00 +/- 2129.10
# Episode length: 394.20 +/- 212.91
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 394      |
# |    mean_reward     | 58       |
# | time/              |          |
# |    total_timesteps | 38000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 886       |
# |    ep_rew_mean     | -5.99e+03 |
# | time/              |           |
# |    fps             | 141       |
# |    iterations      | 19        |
# |    time_elapsed    | 275       |
# |    total_timesteps | 38912     |
# ----------------------------------
# Eval num_timesteps=39000, episode_reward=-3056.00 +/- 8726.83
# Episode length: 705.60 +/- 872.68
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 706          |
# |    mean_reward          | -3.06e+03    |
# | time/                   |              |
# |    total_timesteps      | 39000        |
# | train/                  |              |
# |    approx_kl            | 0.0008648097 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.51e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000729    |
# |    value_loss           | 1.64e+04     |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=-4340.00 +/- 8396.10
# Episode length: 834.00 +/- 839.61
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 834       |
# |    mean_reward     | -4.34e+03 |
# | time/              |           |
# |    total_timesteps | 40000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 870       |
# |    ep_rew_mean     | -5.78e+03 |
# | time/              |           |
# |    fps             | 142       |
# |    iterations      | 20        |
# |    time_elapsed    | 287       |
# |    total_timesteps | 40960     |
# ----------------------------------
# Eval num_timesteps=41000, episode_reward=-6786.00 +/- 8033.06
# Episode length: 1078.60 +/- 803.31
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.08e+03     |
# |    mean_reward          | -6.79e+03    |
# | time/                   |              |
# |    total_timesteps      | 41000        |
# | train/                  |              |
# |    approx_kl            | 0.0010517426 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | 0.462        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.17e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 1.55e+04     |
# ------------------------------------------
# Eval num_timesteps=42000, episode_reward=-9254.00 +/- 14906.81
# Episode length: 1325.40 +/- 1490.68
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.33e+03  |
# |    mean_reward     | -9.25e+03 |
# | time/              |           |
# |    total_timesteps | 42000     |
# ----------------------------------
# Eval num_timesteps=43000, episode_reward=-4926.00 +/- 7599.60
# Episode length: 892.60 +/- 759.96
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 893       |
# |    mean_reward     | -4.93e+03 |
# | time/              |           |
# |    total_timesteps | 43000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 883       |
# |    ep_rew_mean     | -5.86e+03 |
# | time/              |           |
# |    fps             | 139       |
# |    iterations      | 21        |
# |    time_elapsed    | 309       |
# |    total_timesteps | 43008     |
# ----------------------------------
# Eval num_timesteps=44000, episode_reward=1256.00 +/- 1352.89
# Episode length: 274.40 +/- 135.29
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 274           |
# |    mean_reward          | 1.26e+03      |
# | time/                   |               |
# |    total_timesteps      | 44000         |
# | train/                  |               |
# |    approx_kl            | 0.00067551725 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.16         |
# |    explained_variance   | 0.571         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.36e+03      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000811     |
# |    value_loss           | 1.67e+04      |
# -------------------------------------------
# New best mean reward!
# Eval num_timesteps=45000, episode_reward=-3240.00 +/- 8247.46
# Episode length: 724.00 +/- 824.75
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 724       |
# |    mean_reward     | -3.24e+03 |
# | time/              |           |
# |    total_timesteps | 45000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 912       |
# |    ep_rew_mean     | -6.14e+03 |
# | time/              |           |
# |    fps             | 141       |
# |    iterations      | 22        |
# |    time_elapsed    | 318       |
# |    total_timesteps | 45056     |
# ----------------------------------
# Eval num_timesteps=46000, episode_reward=-3136.00 +/- 3738.62
# Episode length: 713.60 +/- 373.86
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 714          |
# |    mean_reward          | -3.14e+03    |
# | time/                   |              |
# |    total_timesteps      | 46000        |
# | train/                  |              |
# |    approx_kl            | 0.0005284651 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.156       |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.61e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000663    |
# |    value_loss           | 1.46e+04     |
# ------------------------------------------
# Eval num_timesteps=47000, episode_reward=-7122.00 +/- 8243.47
# Episode length: 1112.20 +/- 824.35
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.11e+03  |
# |    mean_reward     | -7.12e+03 |
# | time/              |           |
# |    total_timesteps | 47000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 902       |
# |    ep_rew_mean     | -5.99e+03 |
# | time/              |           |
# |    fps             | 141       |
# |    iterations      | 23        |
# |    time_elapsed    | 332       |
# |    total_timesteps | 47104     |
# ----------------------------------
# Eval num_timesteps=48000, episode_reward=928.00 +/- 1168.92
# Episode length: 307.20 +/- 116.89
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 307          |
# |    mean_reward          | 928          |
# | time/                   |              |
# |    total_timesteps      | 48000        |
# | train/                  |              |
# |    approx_kl            | 7.659508e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0969      |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.31e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000281    |
# |    value_loss           | 1.03e+04     |
# ------------------------------------------
# Eval num_timesteps=49000, episode_reward=-16850.00 +/- 8611.35
# Episode length: 2085.00 +/- 861.14
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.08e+03  |
# |    mean_reward     | -1.68e+04 |
# | time/              |           |
# |    total_timesteps | 49000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 902       |
# |    ep_rew_mean     | -5.99e+03 |
# | time/              |           |
# |    fps             | 140       |
# |    iterations      | 24        |
# |    time_elapsed    | 349       |
# |    total_timesteps | 49152     |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-14526.00 +/- 12702.16
# Episode length: 1852.60 +/- 1270.22
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.85e+03    |
# |    mean_reward          | -1.45e+04   |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.001457023 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.197      |
# |    explained_variance   | 6.44e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.32e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 1.81e+04    |
# -----------------------------------------
# Eval num_timesteps=51000, episode_reward=-7780.00 +/- 8996.62
# Episode length: 1178.00 +/- 899.66
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.18e+03  |
# |    mean_reward     | -7.78e+03 |
# | time/              |           |
# |    total_timesteps | 51000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 933       |
# |    ep_rew_mean     | -6.28e+03 |
# | time/              |           |
# |    fps             | 138       |
# |    iterations      | 25        |
# |    time_elapsed    | 370       |
# |    total_timesteps | 51200     |
# ----------------------------------
# Final model saved to ./logs/ppo_gs_baseline_model/final_model

# %% [markdown]
# ### Test Model 1

# %%
# Load the best baseline model
log_dir = "./logs/ppo_sh_baseline_model/"
model_path = log_dir + 'best_model/best_model.zip'
model = PPO.load(model_path)

# Create test environment
env_test = env_gym_sh.TrafficEnvironment()

# %%
# Test the model
num_episodes = 100
file_name = 'ppo_sh_baseline_best_model_test_log.json'
rewards, timesteps = util.test_model(model=model, env=env_test, num_episodes=num_episodes, output_file=file_name)

# %% [markdown]
# ### Analysis of Model 1

# %%
util.plot_test_dotplots(rewards=rewards, timesteps=timesteps, interval=10)
# Out:
# Average reward of 100 episodes is -7852.
# Average timesteps of 100 episodes is 1185.

# %%
util.calculate_action_percentages(log_file=file_name)
# Out:
# Total actions across 100 episodes: 118515
# Action -1: 0.0%
# Action 0: 100.0%
# Action 1: 0.0%

# %%
util.calculate_clearance_rate_percentages(log_file=file_name)
# Out:
# Total timesteps across 100 episodes (including initial states): 118615
# Lane 1:
#   100.0% of timesteps had a clearance rate less than 5
#   100.0% of timesteps had a clearance rate less than 10
# Lane 2:
#   100.0% of timesteps had a clearance rate less than 5
#   100.0% of timesteps had a clearance rate less than 10
# Lane 3:
#   97.4% of timesteps had a clearance rate less than 5
#   98.9% of timesteps had a clearance rate less than 10
# Lane 4:
#   100.0% of timesteps had a clearance rate less than 5
#   100.0% of timesteps had a clearance rate less than 10
# Lane 5:
#   92.5% of timesteps had a clearance rate less than 5
#   95.7% of timesteps had a clearance rate less than 10
