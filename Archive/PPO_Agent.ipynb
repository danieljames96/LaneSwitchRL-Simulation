# %%
import os
import sys

import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import CheckpointCallback
from gymnasium import spaces
import torch

# %% [markdown]
# ## Load Traffic Environment

# %%
# Add the `src` folder to the Python path
sys.path.append(os.path.join(os.path.abspath('..'), 'src'))
import environment_gym as env_gym

# %% [markdown]
# ## Create Evaluation and Test Function

# %%
def evaluate_model(log_path):
    """
    Reads the mean reward from the evaluation log and plots it to monitor convergence.

    Args:
    - log_path (str): Path to the directory containing the log file.
    """
    # Find the monitor CSV file generated by EvalCallback
    monitor_file = os.path.join(log_path, 'evaluations.npz')

    if not os.path.isfile(monitor_file):
        print("Error: Log file not found.")
        return

    # Load evaluation results
    results = np.load(monitor_file)
    mean_rewards = results['results'].mean(axis=1)  # Mean reward per evaluation

    # Plot the mean reward to observe convergence
    plt.plot(mean_rewards)
    plt.xlabel('Evaluation Step (x1000 timesteps)')
    plt.ylabel('Mean Reward')
    plt.title('Model Convergence')
    plt.show()

# %%
def test_model(model_path, env, num_episodes):
    """
    Evaluates the model over a specified number of episodes, records rewards for each episode,
    and plots the rewards.

    Args:
    - model_path (str): Path to the saved model.
    - env (gym.Env): The environment to evaluate the model on.
    - num_episodes (int): Total number of episodes to run the evaluation.

    Returns:
    - episode_rewards (list): List of total rewards for each episode.
    """
    # Load the model
    model = PPO.load(model_path)

    # Initialize a list to store rewards for each episode
    episode_rewards = []

    # Run the model for the specified number of episodes
    for episode in range(num_episodes):
        obs, info = env.reset()
        episode_reward = 0  

        while True:  # Run until the episode ends
            action, _states = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)
            episode_reward += reward  # Accumulate reward

            # Check if the episode is done
            if terminated or truncated:
                episode_reward = round(episode_reward)
                episode_rewards.append(episode_reward)  # Record total reward for the episode
                break  # Exit the loop to start a new episode

    # Calculate average reward
    reward_ave = round(sum(episode_rewards) / num_episodes)
    print(f"Average reward of {num_episodes} episodes is {reward_ave}.")
    
    # Plot the episode rewards
    plt.plot(episode_rewards)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Rewards per Episode')
    plt.show()

    return episode_rewards

# %% [markdown]
# ## Baseline PPO Agent

# %%
# Initialize and vectorize the environment
env = env_gym.TrafficEnvironment()
eval_env = Monitor(env_gym.TrafficEnvironment())

# Define the PPO model with MlpPolicy (a policy network that works well with continuous environments)
model = PPO("MlpPolicy", env, verbose=1)

# Set up evaluation callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path='./logs/ppo_baseline_model',
    log_path='./logs/baseline_results',
    eval_freq=1000,  # Evaluate the model every 1000 steps
    deterministic=True,
    render=False
)

# Train the PPO model
total_timesteps = 50000
model.learn(total_timesteps=total_timesteps, callback=eval_callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Eval num_timesteps=1000, episode_reward=-15361.10 +/- 21185.48
# Episode length: 1292.00 +/- 1412.40
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.29e+03  |
# |    mean_reward     | -1.54e+04 |
# | time/              |           |
# |    total_timesteps | 1000      |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=-18192.68 +/- 32247.50
# Episode length: 1480.20 +/- 2149.42
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.48e+03  |
# |    mean_reward     | -1.82e+04 |
# | time/              |           |
# |    total_timesteps | 2000      |
# ----------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 325  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=-11259.10 +/- 15874.21
# Episode length: 1526.80 +/- 1586.73
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.53e+03   |
# |    mean_reward          | -1.13e+04  |
# | time/                   |            |
# |    total_timesteps      | 3000       |
# | train/                  |            |
# |    approx_kl            | 0.01103699 |
# |    clip_fraction        | 0.084      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.66e+04   |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00529   |
# |    value_loss           | 3.87e+04   |
# ----------------------------------------
# New best mean reward!
# Eval num_timesteps=4000, episode_reward=-5343.46 +/- 7266.90
# Episode length: 935.20 +/- 725.97
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 935       |
# |    mean_reward     | -5.34e+03 |
# | time/              |           |
# |    total_timesteps | 4000      |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.65e+03  |
# |    ep_rew_mean     | -3.12e+04 |
# | time/              |           |
# |    fps             | 321       |
# |    iterations      | 2         |
# |    time_elapsed    | 12        |
# |    total_timesteps | 4096      |
# ----------------------------------
# Eval num_timesteps=5000, episode_reward=-4404.58 +/- 7709.89
# Episode length: 841.00 +/- 770.75
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 841         |
# |    mean_reward          | -4.4e+03    |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.012276017 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0015      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 3.57e+04    |
# -----------------------------------------
# New best mean reward!
# Eval num_timesteps=6000, episode_reward=-18774.98 +/- 5469.13
# Episode length: 2277.60 +/- 546.95
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.28e+03  |
# |    mean_reward     | -1.88e+04 |
# | time/              |           |
# |    total_timesteps | 6000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.04e+03  |
# |    ep_rew_mean     | -2.24e+04 |
# | time/              |           |
# |    fps             | 301       |
# |    iterations      | 3         |
# |    time_elapsed    | 20        |
# |    total_timesteps | 6144      |
# ----------------------------------
# Eval num_timesteps=7000, episode_reward=-5226.28 +/- 10670.61
# Episode length: 923.60 +/- 1066.54
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 924         |
# |    mean_reward          | -5.23e+03   |
# | time/                   |             |
# |    total_timesteps      | 7000        |
# | train/                  |             |
# |    approx_kl            | 0.016928267 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.00059     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 2.99e+04    |
# -----------------------------------------
# Eval num_timesteps=8000, episode_reward=-10174.92 +/- 9572.62
# Episode length: 1418.00 +/- 956.75
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.42e+03  |
# |    mean_reward     | -1.02e+04 |
# | time/              |           |
# |    total_timesteps | 8000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.04e+03  |
# |    ep_rew_mean     | -2.24e+04 |
# | time/              |           |
# |    fps             | 307       |
# |    iterations      | 4         |
# |    time_elapsed    | 26        |
# |    total_timesteps | 8192      |
# ----------------------------------
# Eval num_timesteps=9000, episode_reward=-6406.12 +/- 13544.72
# Episode length: 1041.40 +/- 1353.98
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.04e+03    |
# |    mean_reward          | -6.41e+03   |
# | time/                   |             |
# |    total_timesteps      | 9000        |
# | train/                  |             |
# |    approx_kl            | 0.015729789 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 3e+04       |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=-4807.92 +/- 9237.81
# Episode length: 881.20 +/- 923.50
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 881       |
# |    mean_reward     | -4.81e+03 |
# | time/              |           |
# |    total_timesteps | 10000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.37e+03  |
# |    ep_rew_mean     | -1.33e+04 |
# | time/              |           |
# |    fps             | 318       |
# |    iterations      | 5         |
# |    time_elapsed    | 32        |
# |    total_timesteps | 10240     |
# ----------------------------------
# Eval num_timesteps=11000, episode_reward=-4486.38 +/- 9105.36
# Episode length: 850.00 +/- 909.76
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 850          |
# |    mean_reward          | -4.49e+03    |
# | time/                   |              |
# |    total_timesteps      | 11000        |
# | train/                  |              |
# |    approx_kl            | 0.0048162183 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.807       |
# |    explained_variance   | 4.45e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.68e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00502     |
# |    value_loss           | 1.18e+04     |
# ------------------------------------------
# Eval num_timesteps=12000, episode_reward=-7950.48 +/- 9988.04
# Episode length: 1195.80 +/- 998.16
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.2e+03   |
# |    mean_reward     | -7.95e+03 |
# | time/              |           |
# |    total_timesteps | 12000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.22e+03  |
# |    ep_rew_mean     | -1.11e+04 |
# | time/              |           |
# |    fps             | 325       |
# |    iterations      | 6         |
# |    time_elapsed    | 37        |
# |    total_timesteps | 12288     |
# ----------------------------------
# Eval num_timesteps=13000, episode_reward=-9187.20 +/- 10477.60
# Episode length: 1319.00 +/- 1047.56
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.32e+03     |
# |    mean_reward          | -9.19e+03    |
# | time/                   |              |
# |    total_timesteps      | 13000        |
# | train/                  |              |
# |    approx_kl            | 0.0042951014 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.0013       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.24e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 4.22e+04     |
# ------------------------------------------
# Eval num_timesteps=14000, episode_reward=-11770.54 +/- 8486.45
# Episode length: 1577.20 +/- 848.61
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.58e+03  |
# |    mean_reward     | -1.18e+04 |
# | time/              |           |
# |    total_timesteps | 14000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.06e+03  |
# |    ep_rew_mean     | -9.02e+03 |
# | time/              |           |
# |    fps             | 318       |
# |    iterations      | 7         |
# |    time_elapsed    | 44        |
# |    total_timesteps | 14336     |
# ----------------------------------
# Eval num_timesteps=15000, episode_reward=-651.98 +/- 4808.48
# Episode length: 466.60 +/- 480.08
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 467           |
# |    mean_reward          | -652          |
# | time/                   |               |
# |    total_timesteps      | 15000         |
# | train/                  |               |
# |    approx_kl            | 2.1806423e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.755        |
# |    explained_variance   | 0.172         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.89e+03      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -7.7e-05      |
# |    value_loss           | 1.93e+04      |
# -------------------------------------------
# New best mean reward!
# Eval num_timesteps=16000, episode_reward=-6404.80 +/- 10396.94
# Episode length: 1041.00 +/- 1039.37
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.04e+03 |
# |    mean_reward     | -6.4e+03 |
# | time/              |          |
# |    total_timesteps | 16000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.15e+03  |
# |    ep_rew_mean     | -9.96e+03 |
# | time/              |           |
# |    fps             | 329       |
# |    iterations      | 8         |
# |    time_elapsed    | 49        |
# |    total_timesteps | 16384     |
# ----------------------------------
# Eval num_timesteps=17000, episode_reward=-1771.34 +/- 5118.38
# Episode length: 578.20 +/- 511.07
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 578          |
# |    mean_reward          | -1.77e+03    |
# | time/                   |              |
# |    total_timesteps      | 17000        |
# | train/                  |              |
# |    approx_kl            | 0.0019763375 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+04      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000737    |
# |    value_loss           | 2.72e+04     |
# ------------------------------------------
# Eval num_timesteps=18000, episode_reward=-2241.62 +/- 5746.40
# Episode length: 625.60 +/- 573.50
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 626       |
# |    mean_reward     | -2.24e+03 |
# | time/              |           |
# |    total_timesteps | 18000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 954       |
# |    ep_rew_mean     | -7.47e+03 |
# | time/              |           |
# |    fps             | 341       |
# |    iterations      | 9         |
# |    time_elapsed    | 53        |
# |    total_timesteps | 18432     |
# ----------------------------------
# Eval num_timesteps=19000, episode_reward=-6235.08 +/- 13183.01
# Episode length: 1023.80 +/- 1318.17
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.02e+03      |
# |    mean_reward          | -6.24e+03     |
# | time/                   |               |
# |    total_timesteps      | 19000         |
# | train/                  |               |
# |    approx_kl            | 3.6472455e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.699        |
# |    explained_variance   | 0.183         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.63e+03      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000261     |
# |    value_loss           | 1.35e+04      |
# -------------------------------------------
# Eval num_timesteps=20000, episode_reward=-7406.82 +/- 13148.86
# Episode length: 1141.40 +/- 1314.44
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.14e+03  |
# |    mean_reward     | -7.41e+03 |
# | time/              |           |
# |    total_timesteps | 20000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 925       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    fps             | 341       |
# |    iterations      | 10        |
# |    time_elapsed    | 60        |
# |    total_timesteps | 20480     |
# ----------------------------------
# Eval num_timesteps=21000, episode_reward=1395.48 +/- 1556.87
# Episode length: 262.60 +/- 154.25
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 263          |
# |    mean_reward          | 1.4e+03      |
# | time/                   |              |
# |    total_timesteps      | 21000        |
# | train/                  |              |
# |    approx_kl            | 9.642259e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.42e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000358    |
# |    value_loss           | 1.59e+04     |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=22000, episode_reward=-4569.58 +/- 8490.96
# Episode length: 857.20 +/- 848.93
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 857       |
# |    mean_reward     | -4.57e+03 |
# | time/              |           |
# |    total_timesteps | 22000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 878       |
# |    ep_rew_mean     | -6.45e+03 |
# | time/              |           |
# |    fps             | 351       |
# |    iterations      | 11        |
# |    time_elapsed    | 64        |
# |    total_timesteps | 22528     |
# ----------------------------------
# Eval num_timesteps=23000, episode_reward=-8635.62 +/- 12423.71
# Episode length: 1264.20 +/- 1241.90
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.26e+03      |
# |    mean_reward          | -8.64e+03     |
# | time/                   |               |
# |    total_timesteps      | 23000         |
# | train/                  |               |
# |    approx_kl            | 5.5944285e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.688        |
# |    explained_variance   | 0.272         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.98e+03      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000176     |
# |    value_loss           | 1.7e+04       |
# -------------------------------------------
# Eval num_timesteps=24000, episode_reward=-6290.32 +/- 9006.60
# Episode length: 1029.40 +/- 900.45
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.03e+03  |
# |    mean_reward     | -6.29e+03 |
# | time/              |           |
# |    total_timesteps | 24000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 882       |
# |    ep_rew_mean     | -6.44e+03 |
# | time/              |           |
# |    fps             | 349       |
# |    iterations      | 12        |
# |    time_elapsed    | 70        |
# |    total_timesteps | 24576     |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=-5185.80 +/- 6040.67
# Episode length: 918.80 +/- 604.01
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 919           |
# |    mean_reward          | -5.19e+03     |
# | time/                   |               |
# |    total_timesteps      | 25000         |
# | train/                  |               |
# |    approx_kl            | 0.00027842866 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.682        |
# |    explained_variance   | 0.216         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.48e+04      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000143     |
# |    value_loss           | 2.7e+04       |
# -------------------------------------------
# Eval num_timesteps=26000, episode_reward=-4174.62 +/- 9116.59
# Episode length: 819.00 +/- 910.47
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 819       |
# |    mean_reward     | -4.17e+03 |
# | time/              |           |
# |    total_timesteps | 26000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 844       |
# |    ep_rew_mean     | -5.92e+03 |
# | time/              |           |
# |    fps             | 352       |
# |    iterations      | 13        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 26624     |
# ----------------------------------
# Eval num_timesteps=27000, episode_reward=-15204.40 +/- 13704.67
# Episode length: 1920.60 +/- 1370.35
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.92e+03      |
# |    mean_reward          | -1.52e+04     |
# | time/                   |               |
# |    total_timesteps      | 27000         |
# | train/                  |               |
# |    approx_kl            | 2.8838229e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.669        |
# |    explained_variance   | 0.209         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.91e+04      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 2.92e+04      |
# -------------------------------------------
# Eval num_timesteps=28000, episode_reward=-6889.92 +/- 8279.98
# Episode length: 1089.60 +/- 827.37
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.09e+03  |
# |    mean_reward     | -6.89e+03 |
# | time/              |           |
# |    total_timesteps | 28000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 837       |
# |    ep_rew_mean     | -5.78e+03 |
# | time/              |           |
# |    fps             | 345       |
# |    iterations      | 14        |
# |    time_elapsed    | 83        |
# |    total_timesteps | 28672     |
# ----------------------------------
# Eval num_timesteps=29000, episode_reward=441.26 +/- 1384.80
# Episode length: 356.20 +/- 138.56
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 356           |
# |    mean_reward          | 441           |
# | time/                   |               |
# |    total_timesteps      | 29000         |
# | train/                  |               |
# |    approx_kl            | 2.0296808e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.659        |
# |    explained_variance   | 0.232         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.37e+04      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -9.69e-05     |
# |    value_loss           | 2.63e+04      |
# -------------------------------------------
# Eval num_timesteps=30000, episode_reward=-5523.14 +/- 9125.01
# Episode length: 953.00 +/- 911.97
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 953       |
# |    mean_reward     | -5.52e+03 |
# | time/              |           |
# |    total_timesteps | 30000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 837       |
# |    ep_rew_mean     | -5.78e+03 |
# | time/              |           |
# |    fps             | 351       |
# |    iterations      | 15        |
# |    time_elapsed    | 87        |
# |    total_timesteps | 30720     |
# ----------------------------------
# Eval num_timesteps=31000, episode_reward=-738.26 +/- 3021.72
# Episode length: 474.00 +/- 302.10
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 474          |
# |    mean_reward          | -738         |
# | time/                   |              |
# |    total_timesteps      | 31000        |
# | train/                  |              |
# |    approx_kl            | 0.0063809576 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.00247      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0168      |
# |    value_loss           | 2.49e+04     |
# ------------------------------------------
# Eval num_timesteps=32000, episode_reward=-7169.60 +/- 8967.11
# Episode length: 1118.20 +/- 895.37
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.12e+03  |
# |    mean_reward     | -7.17e+03 |
# | time/              |           |
# |    total_timesteps | 32000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 907       |
# |    ep_rew_mean     | -6.52e+03 |
# | time/              |           |
# |    fps             | 355       |
# |    iterations      | 16        |
# |    time_elapsed    | 92        |
# |    total_timesteps | 32768     |
# ----------------------------------
# Eval num_timesteps=33000, episode_reward=-2089.14 +/- 5210.18
# Episode length: 609.20 +/- 521.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 609           |
# |    mean_reward          | -2.09e+03     |
# | time/                   |               |
# |    total_timesteps      | 33000         |
# | train/                  |               |
# |    approx_kl            | 3.7086866e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.57         |
# |    explained_variance   | 0.124         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.03e+04      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 0.000163      |
# |    value_loss           | 1.94e+04      |
# -------------------------------------------
# Eval num_timesteps=34000, episode_reward=-9596.06 +/- 8410.80
# Episode length: 1360.00 +/- 840.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.36e+03 |
# |    mean_reward     | -9.6e+03 |
# | time/              |          |
# |    total_timesteps | 34000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 827       |
# |    ep_rew_mean     | -5.57e+03 |
# | time/              |           |
# |    fps             | 355       |
# |    iterations      | 17        |
# |    time_elapsed    | 97        |
# |    total_timesteps | 34816     |
# ----------------------------------
# Eval num_timesteps=35000, episode_reward=-14951.26 +/- 7883.13
# Episode length: 1895.20 +/- 788.27
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.9e+03       |
# |    mean_reward          | -1.5e+04      |
# | time/                   |               |
# |    total_timesteps      | 35000         |
# | train/                  |               |
# |    approx_kl            | 1.2084784e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.563        |
# |    explained_variance   | 0.283         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.39e+04      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 2.24e-06      |
# |    value_loss           | 1.92e+04      |
# -------------------------------------------
# Eval num_timesteps=36000, episode_reward=-10986.68 +/- 11455.21
# Episode length: 1500.00 +/- 1143.98
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.5e+03  |
# |    mean_reward     | -1.1e+04 |
# | time/              |          |
# |    total_timesteps | 36000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 801       |
# |    ep_rew_mean     | -5.22e+03 |
# | time/              |           |
# |    fps             | 347       |
# |    iterations      | 18        |
# |    time_elapsed    | 105       |
# |    total_timesteps | 36864     |
# ----------------------------------
# Eval num_timesteps=37000, episode_reward=-7829.22 +/- 10491.19
# Episode length: 1184.40 +/- 1047.62
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.18e+03    |
# |    mean_reward          | -7.83e+03   |
# | time/                   |             |
# |    total_timesteps      | 37000       |
# | train/                  |             |
# |    approx_kl            | 9.76742e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.03e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000286   |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# Eval num_timesteps=38000, episode_reward=475.50 +/- 2333.54
# Episode length: 353.00 +/- 233.06
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 353      |
# |    mean_reward     | 476      |
# | time/              |          |
# |    total_timesteps | 38000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 786       |
# |    ep_rew_mean     | -5.04e+03 |
# | time/              |           |
# |    fps             | 350       |
# |    iterations      | 19        |
# |    time_elapsed    | 110       |
# |    total_timesteps | 38912     |
# ----------------------------------
# Eval num_timesteps=39000, episode_reward=-8022.26 +/- 12567.86
# Episode length: 1203.00 +/- 1256.15
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.2e+03      |
# |    mean_reward          | -8.02e+03    |
# | time/                   |              |
# |    total_timesteps      | 39000        |
# | train/                  |              |
# |    approx_kl            | 7.966516e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.429        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.09e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000234    |
# |    value_loss           | 1.49e+04     |
# ------------------------------------------
# Eval num_timesteps=40000, episode_reward=-10299.46 +/- 13715.14
# Episode length: 1430.20 +/- 1371.33
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.43e+03  |
# |    mean_reward     | -1.03e+04 |
# | time/              |           |
# |    total_timesteps | 40000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | -4.9e+03 |
# | time/              |          |
# |    fps             | 348      |
# |    iterations      | 20       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 40960    |
# ---------------------------------
# Eval num_timesteps=41000, episode_reward=-13398.22 +/- 17601.85
# Episode length: 1740.20 +/- 1759.90
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.74e+03      |
# |    mean_reward          | -1.34e+04     |
# | time/                   |               |
# |    total_timesteps      | 41000         |
# | train/                  |               |
# |    approx_kl            | 1.6134378e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.533        |
# |    explained_variance   | 0.243         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.7e+04       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.00014      |
# |    value_loss           | 4.44e+04      |
# -------------------------------------------
# Eval num_timesteps=42000, episode_reward=-8269.80 +/- 11656.90
# Episode length: 1227.40 +/- 1165.43
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.23e+03  |
# |    mean_reward     | -8.27e+03 |
# | time/              |           |
# |    total_timesteps | 42000     |
# ----------------------------------
# Eval num_timesteps=43000, episode_reward=896.78 +/- 1062.66
# Episode length: 310.80 +/- 105.98
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 311      |
# |    mean_reward     | 897      |
# | time/              |          |
# |    total_timesteps | 43000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | -4.9e+03 |
# | time/              |          |
# |    fps             | 342      |
# |    iterations      | 21       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 43008    |
# ---------------------------------
# Eval num_timesteps=44000, episode_reward=-5798.00 +/- 9167.45
# Episode length: 980.00 +/- 916.58
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 980          |
# |    mean_reward          | -5.8e+03     |
# | time/                   |              |
# |    total_timesteps      | 44000        |
# | train/                  |              |
# |    approx_kl            | 0.0045964527 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.449       |
# |    explained_variance   | -0.000556    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0116      |
# |    value_loss           | 2.29e+04     |
# ------------------------------------------
# Eval num_timesteps=45000, episode_reward=-7283.54 +/- 10895.89
# Episode length: 1128.80 +/- 1089.23
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.13e+03  |
# |    mean_reward     | -7.28e+03 |
# | time/              |           |
# |    total_timesteps | 45000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 818       |
# |    ep_rew_mean     | -5.34e+03 |
# | time/              |           |
# |    fps             | 342       |
# |    iterations      | 22        |
# |    time_elapsed    | 131       |
# |    total_timesteps | 45056     |
# ----------------------------------
# Eval num_timesteps=46000, episode_reward=-4800.14 +/- 9285.10
# Episode length: 880.60 +/- 928.27
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 881          |
# |    mean_reward          | -4.8e+03     |
# | time/                   |              |
# |    total_timesteps      | 46000        |
# | train/                  |              |
# |    approx_kl            | 0.0035386202 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.393       |
# |    explained_variance   | 0.0547       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.71e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 1.98e+04     |
# ------------------------------------------
# Eval num_timesteps=47000, episode_reward=-983.30 +/- 4311.53
# Episode length: 498.60 +/- 431.03
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 499      |
# |    mean_reward     | -983     |
# | time/              |          |
# |    total_timesteps | 47000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 852       |
# |    ep_rew_mean     | -5.68e+03 |
# | time/              |           |
# |    fps             | 346       |
# |    iterations      | 23        |
# |    time_elapsed    | 136       |
# |    total_timesteps | 47104     |
# ----------------------------------
# Eval num_timesteps=48000, episode_reward=-13653.84 +/- 17998.72
# Episode length: 1765.80 +/- 1799.63
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.77e+03     |
# |    mean_reward          | -1.37e+04    |
# | time/                   |              |
# |    total_timesteps      | 48000        |
# | train/                  |              |
# |    approx_kl            | 0.0021866532 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.356       |
# |    explained_variance   | 0.0293       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.04e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 1.85e+04     |
# ------------------------------------------
# Eval num_timesteps=49000, episode_reward=-5925.46 +/- 8340.77
# Episode length: 992.80 +/- 833.99
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 993       |
# |    mean_reward     | -5.93e+03 |
# | time/              |           |
# |    total_timesteps | 49000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 844       |
# |    ep_rew_mean     | -5.56e+03 |
# | time/              |           |
# |    fps             | 342       |
# |    iterations      | 24        |
# |    time_elapsed    | 143       |
# |    total_timesteps | 49152     |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-10508.16 +/- 10891.16
# Episode length: 1451.00 +/- 1088.91
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.45e+03     |
# |    mean_reward          | -1.05e+04    |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 2.837769e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | 0.363        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.65e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -2.66e-05    |
# |    value_loss           | 1.29e+04     |
# ------------------------------------------
# Eval num_timesteps=51000, episode_reward=604.16 +/- 2358.23
# Episode length: 341.40 +/- 234.74
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 341      |
# |    mean_reward     | 604      |
# | time/              |          |
# |    total_timesteps | 51000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 875       |
# |    ep_rew_mean     | -5.86e+03 |
# | time/              |           |
# |    fps             | 344       |
# |    iterations      | 25        |
# |    time_elapsed    | 148       |
# |    total_timesteps | 51200     |
# ----------------------------------

# %%
evaluate_model(log_path='./logs/baseline_results')

# %%
# Model testing
model_path = './logs/ppo_baseline_model/best_model.zip'
env_test = env_gym.TrafficEnvironment()
num_episodes = 200
test_model(model_path=model_path, env=env, num_episodes=num_episodes)
# Out:
# Average reward of 200 episodes is -6306.
# [-33880,
#  1869,
#  -810,
#  1368,
#  -10490,
#  -2626,
#  1811,
#  2655,
#  -15210,
#  1631,
#  -22360,
#  -13039,
#  -324,
#  3266,
#  -15690,
#  -14249,
#  -1929,
#  172,
#  1374,
#  -14028,
#  2292,
#  28,
#  -4560,
#  -28790,
#  1533,
#  -20120,
#  1707,
#  -16740,
#  2810,
#  -1680,
#  275,
#  -10539,
#  1292,
#  2809,
#  -11660,
#  -490,
#  445,
#  2595,
#  -1259,
#  -15830,
#  -1189,
#  -23710,
#  -59,
#  1887,
#  -11700,
#  -1797,
#  403,
#  -7357,
#  953,
#  1901,
#  -498,
#  -1553,
#  -33179,
#  2672,
#  875,
#  -6409,
#  -32610,
#  -1000,
#  -17890,
#  -21059,
#  380,
#  1622,
#  -15258,
#  -20448,
#  1500,
#  1482,
#  -27280,
#  326,
#  1122,
#  2736,
#  2194,
#  396,
#  -4479,
#  3076,
#  -30220,
#  -6010,
#  -1248,
#  2220,
#  -23429,
#  -27000,
#  -1460,
#  2956,
#  -16950,
#  -2498,
#  2475,
#  -247,
#  -919,
#  -9420,
#  -35440,
#  2613,
#  412,
#  -2828,
#  1404,
#  341,
#  -3559,
#  2347,
#  -26409,
#  970,
#  2292,
#  -2198,
#  -418,
#  -3450,
#  2564,
#  1244,
#  -12250,
#  835,
#  -4610,
#  67,
#  1262,
#  961,
#  -1392,
#  -5860,
#  -6010,
#  -4990,
#  -32390,
#  281,
#  -11679,
#  -8200,
#  -15109,
#  -15050,
#  -19840,
#  2237,
#  -9220,
#  871,
#  1409,
#  -14129,
#  2326,
#  -16770,
#  -29870,
#  -16410,
#  -8020,
#  -14599,
#  551,
#  -19490,
#  -17589,
#  -11050,
#  1480,
#  -31459,
#  48,
#  -568,
#  -11690,
#  1913,
#  2971,
#  -1298,
#  -412,
#  2912,
#  703,
#  -6930,
#  -416,
#  -1155,
#  1240,
#  -185,
#  -1649,
#  2334,
#  2153,
#  1036,
#  1661,
#  1601,
#  502,
#  -3688,
#  717,
#  -21610,
#  -12150,
#  -8740,
#  -17880,
#  -19980,
#  2723,
#  1690,
#  -20880,
#  -80,
#  1870,
#  1056,
#  -20890,
#  -20680,
#  -1228,
#  113,
#  1892,
#  1833,
#  1956,
#  524,
#  2233,
#  -27169,
#  -21579,
#  -23820,
#  1487,
#  -14449,
#  791,
#  -33610,
#  -3930,
#  1817,
#  -8170,
#  -28490,
#  2627,
#  451,
#  2874,
#  2590,
#  -12219,
#  -17950,
#  -13560,
#  -16659]

# %% [markdown]
# ## Finetune PPO Agent

# %%
# Initialize and vectorize the environment
env = env_gym.TrafficEnvironment()
eval_env = Monitor(env_gym.TrafficEnvironment())

# Set up evaluation callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path='./logs/ppo_finetune_model',
    log_path='./logs/finetune_results',
    eval_freq=1000,  # Evaluate the model every 1000 steps
    deterministic=True,
    render=False
)

# Define the PPO model with MlpPolicy
model = PPO(
    "MlpPolicy", 
    env, 
    verbose=1,
    learning_rate=2.5e-4,         
    n_steps=4096,               
    batch_size=128,              
    gae_lambda=0.95,            
    gamma=0.99,                 
    clip_range=0.1,
    clip_range_vf=0.1,
    n_epochs=20,
    ent_coef=0.005,
    target_kl=0.01
)

# Train the PPO model
total_timesteps = 100000
model.learn(total_timesteps=total_timesteps, callback=eval_callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Eval num_timesteps=1000, episode_reward=-6000.06 +/- 12659.68
# Episode length: 667.00 +/- 843.97
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 667      |
# |    mean_reward     | -6e+03   |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=-7674.52 +/- 9481.85
# Episode length: 778.80 +/- 631.66
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 779       |
# |    mean_reward     | -7.67e+03 |
# | time/              |           |
# |    total_timesteps | 2000      |
# ----------------------------------
# Eval num_timesteps=3000, episode_reward=-26446.26 +/- 22616.88
# Episode length: 2029.80 +/- 1507.76
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.03e+03  |
# |    mean_reward     | -2.64e+04 |
# | time/              |           |
# |    total_timesteps | 3000      |
# ----------------------------------
# Eval num_timesteps=4000, episode_reward=-28065.26 +/- 21933.23
# Episode length: 2137.80 +/- 1462.10
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.14e+03  |
# |    mean_reward     | -2.81e+04 |
# | time/              |           |
# |    total_timesteps | 4000      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -1.2e+04 |
# | time/              |          |
# |    fps             | 137      |
# |    iterations      | 1        |
# |    time_elapsed    | 29       |
# |    total_timesteps | 4096     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-9733.44 +/- 13899.07
# Episode length: 1359.20 +/- 1392.76
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.36e+03     |
# |    mean_reward          | -9.73e+03    |
# | time/                   |              |
# |    total_timesteps      | 5000         |
# | train/                  |              |
# |    approx_kl            | 0.0027849292 |
# |    clip_fraction        | 0.0738       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000167    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.65e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 3.28e+04     |
# ------------------------------------------
# Eval num_timesteps=6000, episode_reward=-4211.04 +/- 7445.85
# Episode length: 807.80 +/- 746.28
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 808       |
# |    mean_reward     | -4.21e+03 |
# | time/              |           |
# |    total_timesteps | 6000      |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=7000, episode_reward=-13591.26 +/- 13549.43
# Episode length: 1746.80 +/- 1358.73
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.75e+03  |
# |    mean_reward     | -1.36e+04 |
# | time/              |           |
# |    total_timesteps | 7000      |
# ----------------------------------
# Eval num_timesteps=8000, episode_reward=-8962.48 +/- 11704.15
# Episode length: 1284.40 +/- 1171.39
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.28e+03  |
# |    mean_reward     | -8.96e+03 |
# | time/              |           |
# |    total_timesteps | 8000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 934       |
# |    ep_rew_mean     | -8.41e+03 |
# | time/              |           |
# |    fps             | 132       |
# |    iterations      | 2         |
# |    time_elapsed    | 61        |
# |    total_timesteps | 8192      |
# ----------------------------------
# Eval num_timesteps=9000, episode_reward=-2942.82 +/- 7015.63
# Episode length: 687.20 +/- 704.44
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 687          |
# |    mean_reward          | -2.94e+03    |
# | time/                   |              |
# |    total_timesteps      | 9000         |
# | train/                  |              |
# |    approx_kl            | 0.0030181664 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000276    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.36e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 2.93e+04     |
# ------------------------------------------
# New best mean reward!
# Eval num_timesteps=10000, episode_reward=-3342.20 +/- 3363.15
# Episode length: 729.00 +/- 339.40
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 729       |
# |    mean_reward     | -3.34e+03 |
# | time/              |           |
# |    total_timesteps | 10000     |
# ----------------------------------
# Eval num_timesteps=11000, episode_reward=-5706.24 +/- 8967.35
# Episode length: 968.40 +/- 896.83
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 968       |
# |    mean_reward     | -5.71e+03 |
# | time/              |           |
# |    total_timesteps | 11000     |
# ----------------------------------
# Eval num_timesteps=12000, episode_reward=-4663.06 +/- 11131.36
# Episode length: 854.20 +/- 1117.40
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 854       |
# |    mean_reward     | -4.66e+03 |
# | time/              |           |
# |    total_timesteps | 12000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.07e+03  |
# |    ep_rew_mean     | -1.01e+04 |
# | time/              |           |
# |    fps             | 144       |
# |    iterations      | 3         |
# |    time_elapsed    | 84        |
# |    total_timesteps | 12288     |
# ----------------------------------
# Eval num_timesteps=13000, episode_reward=-18545.50 +/- 11222.81
# Episode length: 2250.20 +/- 1122.34
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2.25e+03     |
# |    mean_reward          | -1.85e+04    |
# | time/                   |              |
# |    total_timesteps      | 13000        |
# | train/                  |              |
# |    approx_kl            | 0.0016512552 |
# |    clip_fraction        | 0.0582       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000217    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.51e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 2.86e+04     |
# ------------------------------------------
# Eval num_timesteps=14000, episode_reward=-2000.22 +/- 5737.40
# Episode length: 595.40 +/- 574.06
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 595      |
# |    mean_reward     | -2e+03   |
# | time/              |          |
# |    total_timesteps | 14000    |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=15000, episode_reward=-6505.64 +/- 7825.80
# Episode length: 1043.80 +/- 782.16
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.04e+03  |
# |    mean_reward     | -6.51e+03 |
# | time/              |           |
# |    total_timesteps | 15000     |
# ----------------------------------
# Eval num_timesteps=16000, episode_reward=-12283.38 +/- 8553.42
# Episode length: 1624.20 +/- 856.00
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.62e+03  |
# |    mean_reward     | -1.23e+04 |
# | time/              |           |
# |    total_timesteps | 16000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.17e+03  |
# |    ep_rew_mean     | -1.14e+04 |
# | time/              |           |
# |    fps             | 138       |
# |    iterations      | 4         |
# |    time_elapsed    | 117       |
# |    total_timesteps | 16384     |
# ----------------------------------
# Eval num_timesteps=17000, episode_reward=-2319.32 +/- 8297.02
# Episode length: 628.60 +/- 829.77
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 629         |
# |    mean_reward          | -2.32e+03   |
# | time/                   |             |
# |    total_timesteps      | 17000       |
# | train/                  |             |
# |    approx_kl            | 0.004011156 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.1         |
# |    clip_range_vf        | 0.1         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.00051     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.97e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 4.06e+04    |
# -----------------------------------------
# Eval num_timesteps=18000, episode_reward=-12588.26 +/- 11866.26
# Episode length: 1655.40 +/- 1186.33
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.66e+03  |
# |    mean_reward     | -1.26e+04 |
# | time/              |           |
# |    total_timesteps | 18000     |
# ----------------------------------
# Eval num_timesteps=19000, episode_reward=-2383.72 +/- 4355.26
# Episode length: 635.60 +/- 434.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 636       |
# |    mean_reward     | -2.38e+03 |
# | time/              |           |
# |    total_timesteps | 19000     |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=1444.28 +/- 1099.06
# Episode length: 251.20 +/- 110.54
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 251      |
# |    mean_reward     | 1.44e+03 |
# | time/              |          |
# |    total_timesteps | 20000    |
# ---------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.28e+03  |
# |    ep_rew_mean     | -1.26e+04 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 5         |
# |    time_elapsed    | 140       |
# |    total_timesteps | 20480     |
# ----------------------------------
# Eval num_timesteps=21000, episode_reward=-12225.98 +/- 14982.46
# Episode length: 1612.40 +/- 1500.43
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.61e+03     |
# |    mean_reward          | -1.22e+04    |
# | time/                   |              |
# |    total_timesteps      | 21000        |
# | train/                  |              |
# |    approx_kl            | 0.0044075726 |
# |    clip_fraction        | 0.148        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.000582     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.38e+04     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 2.91e+04     |
# ------------------------------------------
# Eval num_timesteps=22000, episode_reward=-12218.46 +/- 10249.54
# Episode length: 1615.20 +/- 1026.58
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.62e+03  |
# |    mean_reward     | -1.22e+04 |
# | time/              |           |
# |    total_timesteps | 22000     |
# ----------------------------------
# Eval num_timesteps=23000, episode_reward=-6809.58 +/- 14603.68
# Episode length: 1069.40 +/- 1463.15
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.07e+03  |
# |    mean_reward     | -6.81e+03 |
# | time/              |           |
# |    total_timesteps | 23000     |
# ----------------------------------
# Eval num_timesteps=24000, episode_reward=-8948.34 +/- 13022.96
# Episode length: 1285.80 +/- 1303.92
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.29e+03  |
# |    mean_reward     | -8.95e+03 |
# | time/              |           |
# |    total_timesteps | 24000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.36e+03  |
# |    ep_rew_mean     | -1.36e+04 |
# | time/              |           |
# |    fps             | 141       |
# |    iterations      | 6         |
# |    time_elapsed    | 174       |
# |    total_timesteps | 24576     |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=-2387.66 +/- 3567.72
# Episode length: 629.60 +/- 358.56
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 630          |
# |    mean_reward          | -2.39e+03    |
# | time/                   |              |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 0.0032701974 |
# |    clip_fraction        | 0.0749       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.989       |
# |    explained_variance   | 0.000586     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.59e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 3.24e+04     |
# ------------------------------------------
# Eval num_timesteps=26000, episode_reward=-11733.68 +/- 11884.53
# Episode length: 1566.60 +/- 1189.54
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.57e+03  |
# |    mean_reward     | -1.17e+04 |
# | time/              |           |
# |    total_timesteps | 26000     |
# ----------------------------------
# Eval num_timesteps=27000, episode_reward=-2791.04 +/- 5710.18
# Episode length: 671.60 +/- 571.67
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 672       |
# |    mean_reward     | -2.79e+03 |
# | time/              |           |
# |    total_timesteps | 27000     |
# ----------------------------------
# Eval num_timesteps=28000, episode_reward=-2341.32 +/- 2572.78
# Episode length: 628.00 +/- 258.85
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 628       |
# |    mean_reward     | -2.34e+03 |
# | time/              |           |
# |    total_timesteps | 28000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.27e+03  |
# |    ep_rew_mean     | -1.23e+04 |
# | time/              |           |
# |    fps             | 144       |
# |    iterations      | 7         |
# |    time_elapsed    | 198       |
# |    total_timesteps | 28672     |
# ----------------------------------
# Eval num_timesteps=29000, episode_reward=-80.84 +/- 1696.68
# Episode length: 403.20 +/- 170.12
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 403          |
# |    mean_reward          | -80.8        |
# | time/                   |              |
# |    total_timesteps      | 29000        |
# | train/                  |              |
# |    approx_kl            | 0.0034229115 |
# |    clip_fraction        | 0.146        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.00019      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.59e+04     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 3.17e+04     |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=-2399.56 +/- 4121.09
# Episode length: 635.80 +/- 411.50
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 636      |
# |    mean_reward     | -2.4e+03 |
# | time/              |          |
# |    total_timesteps | 30000    |
# ---------------------------------
# Eval num_timesteps=31000, episode_reward=-3866.22 +/- 7587.09
# Episode length: 780.80 +/- 759.42
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 781       |
# |    mean_reward     | -3.87e+03 |
# | time/              |           |
# |    total_timesteps | 31000     |
# ----------------------------------
# Eval num_timesteps=32000, episode_reward=-5619.00 +/- 7028.97
# Episode length: 958.00 +/- 702.07
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 958       |
# |    mean_reward     | -5.62e+03 |
# | time/              |           |
# |    total_timesteps | 32000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.39e+03  |
# |    ep_rew_mean     | -1.38e+04 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 8         |
# |    time_elapsed    | 219       |
# |    total_timesteps | 32768     |
# ----------------------------------
# Eval num_timesteps=33000, episode_reward=-6152.92 +/- 7721.39
# Episode length: 1009.60 +/- 772.52
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | -6.15e+03    |
# | time/                   |              |
# |    total_timesteps      | 33000        |
# | train/                  |              |
# |    approx_kl            | 0.0032553514 |
# |    clip_fraction        | 0.171        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.896       |
# |    explained_variance   | 0.00149      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.41e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00721     |
# |    value_loss           | 2.84e+04     |
# ------------------------------------------
# Eval num_timesteps=34000, episode_reward=-2154.08 +/- 7424.93
# Episode length: 609.00 +/- 742.79
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 609       |
# |    mean_reward     | -2.15e+03 |
# | time/              |           |
# |    total_timesteps | 34000     |
# ----------------------------------
# Eval num_timesteps=35000, episode_reward=-5190.44 +/- 12799.14
# Episode length: 911.20 +/- 1280.40
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 911       |
# |    mean_reward     | -5.19e+03 |
# | time/              |           |
# |    total_timesteps | 35000     |
# ----------------------------------
# Eval num_timesteps=36000, episode_reward=946.18 +/- 1488.53
# Episode length: 296.20 +/- 149.77
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 296      |
# |    mean_reward     | 946      |
# | time/              |          |
# |    total_timesteps | 36000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.17e+03  |
# |    ep_rew_mean     | -1.08e+04 |
# | time/              |           |
# |    fps             | 152       |
# |    iterations      | 9         |
# |    time_elapsed    | 241       |
# |    total_timesteps | 36864     |
# ----------------------------------
# Eval num_timesteps=37000, episode_reward=-210.62 +/- 1751.34
# Episode length: 416.20 +/- 175.47
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 416           |
# |    mean_reward          | -211          |
# | time/                   |               |
# |    total_timesteps      | 37000         |
# | train/                  |               |
# |    approx_kl            | 0.00079428125 |
# |    clip_fraction        | 0.044         |
# |    clip_range           | 0.1           |
# |    clip_range_vf        | 0.1           |
# |    entropy_loss         | -0.899        |
# |    explained_variance   | 0.000101      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.42e+04      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000975     |
# |    value_loss           | 2.45e+04      |
# -------------------------------------------
# Eval num_timesteps=38000, episode_reward=-3703.00 +/- 5997.87
# Episode length: 764.20 +/- 600.33
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 764      |
# |    mean_reward     | -3.7e+03 |
# | time/              |          |
# |    total_timesteps | 38000    |
# ---------------------------------
# Eval num_timesteps=39000, episode_reward=-10399.04 +/- 11560.21
# Episode length: 1434.60 +/- 1157.38
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.43e+03  |
# |    mean_reward     | -1.04e+04 |
# | time/              |           |
# |    total_timesteps | 39000     |
# ----------------------------------
# Eval num_timesteps=40000, episode_reward=944.16 +/- 1090.27
# Episode length: 301.60 +/- 108.29
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 302      |
# |    mean_reward     | 944      |
# | time/              |          |
# |    total_timesteps | 40000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.21e+03  |
# |    ep_rew_mean     | -1.13e+04 |
# | time/              |           |
# |    fps             | 154       |
# |    iterations      | 10        |
# |    time_elapsed    | 264       |
# |    total_timesteps | 40960     |
# ----------------------------------
# Eval num_timesteps=41000, episode_reward=-10649.82 +/- 15124.02
# Episode length: 1460.80 +/- 1512.74
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.46e+03    |
# |    mean_reward          | -1.06e+04   |
# | time/                   |             |
# |    total_timesteps      | 41000       |
# | train/                  |             |
# |    approx_kl            | 0.003048292 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.1         |
# |    clip_range_vf        | 0.1         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.00174     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.68e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00728    |
# |    value_loss           | 3.32e+04    |
# -----------------------------------------
# Eval num_timesteps=42000, episode_reward=-8937.72 +/- 12086.87
# Episode length: 1288.40 +/- 1208.74
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.29e+03  |
# |    mean_reward     | -8.94e+03 |
# | time/              |           |
# |    total_timesteps | 42000     |
# ----------------------------------
# Eval num_timesteps=43000, episode_reward=-6324.60 +/- 6141.02
# Episode length: 1027.80 +/- 614.13
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.03e+03  |
# |    mean_reward     | -6.32e+03 |
# | time/              |           |
# |    total_timesteps | 43000     |
# ----------------------------------
# Eval num_timesteps=44000, episode_reward=-5284.64 +/- 6885.69
# Episode length: 925.40 +/- 688.01
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 925       |
# |    mean_reward     | -5.28e+03 |
# | time/              |           |
# |    total_timesteps | 44000     |
# ----------------------------------
# Eval num_timesteps=45000, episode_reward=-2836.72 +/- 8968.38
# Episode length: 679.20 +/- 895.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 679       |
# |    mean_reward     | -2.84e+03 |
# | time/              |           |
# |    total_timesteps | 45000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.21e+03  |
# |    ep_rew_mean     | -1.11e+04 |
# | time/              |           |
# |    fps             | 151       |
# |    iterations      | 11        |
# |    time_elapsed    | 297       |
# |    total_timesteps | 45056     |
# ----------------------------------
# Eval num_timesteps=46000, episode_reward=-16058.70 +/- 10388.52
# Episode length: 2000.40 +/- 1041.17
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2e+03        |
# |    mean_reward          | -1.61e+04    |
# | time/                   |              |
# |    total_timesteps      | 46000        |
# | train/                  |              |
# |    approx_kl            | 0.0017634467 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.000384     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.59e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 2.75e+04     |
# ------------------------------------------
# Eval num_timesteps=47000, episode_reward=-4550.36 +/- 5264.34
# Episode length: 851.20 +/- 526.91
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 851       |
# |    mean_reward     | -4.55e+03 |
# | time/              |           |
# |    total_timesteps | 47000     |
# ----------------------------------
# Eval num_timesteps=48000, episode_reward=-5033.40 +/- 7865.70
# Episode length: 899.20 +/- 785.75
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 899       |
# |    mean_reward     | -5.03e+03 |
# | time/              |           |
# |    total_timesteps | 48000     |
# ----------------------------------
# Eval num_timesteps=49000, episode_reward=-6797.90 +/- 7037.92
# Episode length: 1076.00 +/- 703.21
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.08e+03 |
# |    mean_reward     | -6.8e+03 |
# | time/              |          |
# |    total_timesteps | 49000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.23e+03  |
# |    ep_rew_mean     | -1.13e+04 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 12        |
# |    time_elapsed    | 327       |
# |    total_timesteps | 49152     |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-1483.38 +/- 2300.94
# Episode length: 545.00 +/- 227.28
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 545          |
# |    mean_reward          | -1.48e+03    |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0020676565 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.752       |
# |    explained_variance   | 0.000786     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.53e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00465     |
# |    value_loss           | 3.07e+04     |
# ------------------------------------------
# Eval num_timesteps=51000, episode_reward=-11162.00 +/- 8005.40
# Episode length: 1511.80 +/- 801.57
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.51e+03  |
# |    mean_reward     | -1.12e+04 |
# | time/              |           |
# |    total_timesteps | 51000     |
# ----------------------------------
# Eval num_timesteps=52000, episode_reward=-2864.22 +/- 6569.91
# Episode length: 681.00 +/- 657.57
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 681       |
# |    mean_reward     | -2.86e+03 |
# | time/              |           |
# |    total_timesteps | 52000     |
# ----------------------------------
# Eval num_timesteps=53000, episode_reward=-21321.40 +/- 9946.93
# Episode length: 2526.80 +/- 995.59
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.53e+03  |
# |    mean_reward     | -2.13e+04 |
# | time/              |           |
# |    total_timesteps | 53000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.28e+03  |
# |    ep_rew_mean     | -1.17e+04 |
# | time/              |           |
# |    fps             | 148       |
# |    iterations      | 13        |
# |    time_elapsed    | 359       |
# |    total_timesteps | 53248     |
# ----------------------------------
# Eval num_timesteps=54000, episode_reward=-4851.58 +/- 10171.10
# Episode length: 879.80 +/- 1015.56
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 880         |
# |    mean_reward          | -4.85e+03   |
# | time/                   |             |
# |    total_timesteps      | 54000       |
# | train/                  |             |
# |    approx_kl            | 0.001804957 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.1         |
# |    clip_range_vf        | 0.1         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.000419    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.17e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 2.42e+04    |
# -----------------------------------------
# Eval num_timesteps=55000, episode_reward=-18823.60 +/- 11269.69
# Episode length: 2277.60 +/- 1127.13
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.28e+03  |
# |    mean_reward     | -1.88e+04 |
# | time/              |           |
# |    total_timesteps | 55000     |
# ----------------------------------
# Eval num_timesteps=56000, episode_reward=-6882.24 +/- 13049.97
# Episode length: 1082.80 +/- 1304.42
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.08e+03  |
# |    mean_reward     | -6.88e+03 |
# | time/              |           |
# |    total_timesteps | 56000     |
# ----------------------------------
# Eval num_timesteps=57000, episode_reward=-2651.60 +/- 8150.76
# Episode length: 659.80 +/- 815.07
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 660       |
# |    mean_reward     | -2.65e+03 |
# | time/              |           |
# |    total_timesteps | 57000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.17e+03  |
# |    ep_rew_mean     | -1.03e+04 |
# | time/              |           |
# |    fps             | 146       |
# |    iterations      | 14        |
# |    time_elapsed    | 390       |
# |    total_timesteps | 57344     |
# ----------------------------------
# Eval num_timesteps=58000, episode_reward=-2586.78 +/- 5113.13
# Episode length: 652.60 +/- 510.61
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 653          |
# |    mean_reward          | -2.59e+03    |
# | time/                   |              |
# |    total_timesteps      | 58000        |
# | train/                  |              |
# |    approx_kl            | 0.0012801613 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 4.94e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.98e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 2.49e+04     |
# ------------------------------------------
# Eval num_timesteps=59000, episode_reward=-9313.88 +/- 10958.37
# Episode length: 1325.80 +/- 1095.31
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.33e+03  |
# |    mean_reward     | -9.31e+03 |
# | time/              |           |
# |    total_timesteps | 59000     |
# ----------------------------------
# Eval num_timesteps=60000, episode_reward=-3451.22 +/- 5800.15
# Episode length: 740.00 +/- 580.25
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 740       |
# |    mean_reward     | -3.45e+03 |
# | time/              |           |
# |    total_timesteps | 60000     |
# ----------------------------------
# Eval num_timesteps=61000, episode_reward=-9649.80 +/- 12845.00
# Episode length: 1358.00 +/- 1284.70
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.36e+03  |
# |    mean_reward     | -9.65e+03 |
# | time/              |           |
# |    total_timesteps | 61000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.21e+03  |
# |    ep_rew_mean     | -1.08e+04 |
# | time/              |           |
# |    fps             | 147       |
# |    iterations      | 15        |
# |    time_elapsed    | 417       |
# |    total_timesteps | 61440     |
# ----------------------------------
# Eval num_timesteps=62000, episode_reward=-1113.36 +/- 4855.36
# Episode length: 507.20 +/- 484.38
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 507          |
# |    mean_reward          | -1.11e+03    |
# | time/                   |              |
# |    total_timesteps      | 62000        |
# | train/                  |              |
# |    approx_kl            | 0.0016309044 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.635       |
# |    explained_variance   | 0.004        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.43e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00485     |
# |    value_loss           | 2.88e+04     |
# ------------------------------------------
# Eval num_timesteps=63000, episode_reward=-3479.22 +/- 9783.30
# Episode length: 739.60 +/- 978.67
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 740       |
# |    mean_reward     | -3.48e+03 |
# | time/              |           |
# |    total_timesteps | 63000     |
# ----------------------------------
# Eval num_timesteps=64000, episode_reward=-11999.46 +/- 14343.68
# Episode length: 1593.20 +/- 1434.27
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.59e+03 |
# |    mean_reward     | -1.2e+04 |
# | time/              |          |
# |    total_timesteps | 64000    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=-858.24 +/- 2194.34
# Episode length: 479.60 +/- 219.70
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 480      |
# |    mean_reward     | -858     |
# | time/              |          |
# |    total_timesteps | 65000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.25e+03  |
# |    ep_rew_mean     | -1.11e+04 |
# | time/              |           |
# |    fps             | 148       |
# |    iterations      | 16        |
# |    time_elapsed    | 440       |
# |    total_timesteps | 65536     |
# ----------------------------------
# Eval num_timesteps=66000, episode_reward=-10098.00 +/- 13413.36
# Episode length: 1402.00 +/- 1342.52
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.4e+03     |
# |    mean_reward          | -1.01e+04   |
# | time/                   |             |
# |    total_timesteps      | 66000       |
# | train/                  |             |
# |    approx_kl            | 0.000322684 |
# |    clip_fraction        | 0.0241      |
# |    clip_range           | 0.1         |
# |    clip_range_vf        | 0.1         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.000241    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.19e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 2.41e+04    |
# -----------------------------------------
# Eval num_timesteps=67000, episode_reward=-2517.64 +/- 5390.61
# Episode length: 647.00 +/- 537.29
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 647       |
# |    mean_reward     | -2.52e+03 |
# | time/              |           |
# |    total_timesteps | 67000     |
# ----------------------------------
# Eval num_timesteps=68000, episode_reward=-6215.68 +/- 10638.74
# Episode length: 1010.80 +/- 1066.65
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.01e+03  |
# |    mean_reward     | -6.22e+03 |
# | time/              |           |
# |    total_timesteps | 68000     |
# ----------------------------------
# Eval num_timesteps=69000, episode_reward=-568.14 +/- 4059.05
# Episode length: 446.80 +/- 405.69
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 447      |
# |    mean_reward     | -568     |
# | time/              |          |
# |    total_timesteps | 69000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.3e+03   |
# |    ep_rew_mean     | -1.16e+04 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 17        |
# |    time_elapsed    | 464       |
# |    total_timesteps | 69632     |
# ----------------------------------
# Eval num_timesteps=70000, episode_reward=-5699.98 +/- 6239.07
# Episode length: 963.20 +/- 622.93
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 963          |
# |    mean_reward          | -5.7e+03     |
# | time/                   |              |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0011432159 |
# |    clip_fraction        | 0.0815       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.57        |
# |    explained_variance   | 0.000457     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.35e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 2.72e+04     |
# ------------------------------------------
# Eval num_timesteps=71000, episode_reward=-3455.80 +/- 7993.07
# Episode length: 741.00 +/- 798.95
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 741       |
# |    mean_reward     | -3.46e+03 |
# | time/              |           |
# |    total_timesteps | 71000     |
# ----------------------------------
# Eval num_timesteps=72000, episode_reward=-5698.74 +/- 9507.66
# Episode length: 964.40 +/- 951.07
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 964      |
# |    mean_reward     | -5.7e+03 |
# | time/              |          |
# |    total_timesteps | 72000    |
# ---------------------------------
# Eval num_timesteps=73000, episode_reward=-10440.36 +/- 13574.15
# Episode length: 1438.20 +/- 1357.28
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.44e+03  |
# |    mean_reward     | -1.04e+04 |
# | time/              |           |
# |    total_timesteps | 73000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.3e+03   |
# |    ep_rew_mean     | -1.15e+04 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 18        |
# |    time_elapsed    | 492       |
# |    total_timesteps | 73728     |
# ----------------------------------
# Eval num_timesteps=74000, episode_reward=-5213.50 +/- 10330.76
# Episode length: 913.00 +/- 1032.96
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 913          |
# |    mean_reward          | -5.21e+03    |
# | time/                   |              |
# |    total_timesteps      | 74000        |
# | train/                  |              |
# |    approx_kl            | 0.0008933286 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | 5.3e-05      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.39e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 3.02e+04     |
# ------------------------------------------
# Eval num_timesteps=75000, episode_reward=-9919.26 +/- 12377.23
# Episode length: 1386.60 +/- 1237.40
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.39e+03  |
# |    mean_reward     | -9.92e+03 |
# | time/              |           |
# |    total_timesteps | 75000     |
# ----------------------------------
# Eval num_timesteps=76000, episode_reward=-11626.82 +/- 14683.40
# Episode length: 1554.20 +/- 1470.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.55e+03  |
# |    mean_reward     | -1.16e+04 |
# | time/              |           |
# |    total_timesteps | 76000     |
# ----------------------------------
# Eval num_timesteps=77000, episode_reward=-2832.62 +/- 6248.48
# Episode length: 681.00 +/- 621.82
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 681       |
# |    mean_reward     | -2.83e+03 |
# | time/              |           |
# |    total_timesteps | 77000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.34e+03  |
# |    ep_rew_mean     | -1.19e+04 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 19        |
# |    time_elapsed    | 522       |
# |    total_timesteps | 77824     |
# ----------------------------------
# Eval num_timesteps=78000, episode_reward=-12050.82 +/- 11292.82
# Episode length: 1596.60 +/- 1132.25
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.6e+03       |
# |    mean_reward          | -1.21e+04     |
# | time/                   |               |
# |    total_timesteps      | 78000         |
# | train/                  |               |
# |    approx_kl            | 0.00025313697 |
# |    clip_fraction        | 0.00719       |
# |    clip_range           | 0.1           |
# |    clip_range_vf        | 0.1           |
# |    entropy_loss         | -0.542        |
# |    explained_variance   | 0.000203      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.31e+04      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000245     |
# |    value_loss           | 2.62e+04      |
# -------------------------------------------
# Eval num_timesteps=79000, episode_reward=-6386.62 +/- 7698.76
# Episode length: 1033.60 +/- 769.13
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.03e+03  |
# |    mean_reward     | -6.39e+03 |
# | time/              |           |
# |    total_timesteps | 79000     |
# ----------------------------------
# Eval num_timesteps=80000, episode_reward=-623.80 +/- 5231.60
# Episode length: 456.00 +/- 523.87
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 456      |
# |    mean_reward     | -624     |
# | time/              |          |
# |    total_timesteps | 80000    |
# ---------------------------------
# Eval num_timesteps=81000, episode_reward=400.80 +/- 1176.63
# Episode length: 354.60 +/- 118.27
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 355      |
# |    mean_reward     | 401      |
# | time/              |          |
# |    total_timesteps | 81000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.29e+03  |
# |    ep_rew_mean     | -1.13e+04 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 20        |
# |    time_elapsed    | 546       |
# |    total_timesteps | 81920     |
# ----------------------------------
# Eval num_timesteps=82000, episode_reward=-17749.36 +/- 16498.76
# Episode length: 2170.00 +/- 1648.92
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2.17e+03     |
# |    mean_reward          | -1.77e+04    |
# | time/                   |              |
# |    total_timesteps      | 82000        |
# | train/                  |              |
# |    approx_kl            | 0.0013146678 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 9.61e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.02e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000986    |
# |    value_loss           | 2.26e+04     |
# ------------------------------------------
# Eval num_timesteps=83000, episode_reward=-3538.14 +/- 5464.56
# Episode length: 748.20 +/- 545.89
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 748       |
# |    mean_reward     | -3.54e+03 |
# | time/              |           |
# |    total_timesteps | 83000     |
# ----------------------------------
# Eval num_timesteps=84000, episode_reward=-14162.22 +/- 13464.24
# Episode length: 1810.80 +/- 1347.92
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.81e+03  |
# |    mean_reward     | -1.42e+04 |
# | time/              |           |
# |    total_timesteps | 84000     |
# ----------------------------------
# Eval num_timesteps=85000, episode_reward=-9511.36 +/- 8116.70
# Episode length: 1345.40 +/- 811.87
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.35e+03  |
# |    mean_reward     | -9.51e+03 |
# | time/              |           |
# |    total_timesteps | 85000     |
# ----------------------------------
# Eval num_timesteps=86000, episode_reward=-14578.82 +/- 14303.86
# Episode length: 1851.40 +/- 1430.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.85e+03  |
# |    mean_reward     | -1.46e+04 |
# | time/              |           |
# |    total_timesteps | 86000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.22e+03  |
# |    ep_rew_mean     | -1.04e+04 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 21        |
# |    time_elapsed    | 590       |
# |    total_timesteps | 86016     |
# ----------------------------------
# Eval num_timesteps=87000, episode_reward=-14798.68 +/- 12050.51
# Episode length: 1873.60 +/- 1204.52
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.87e+03     |
# |    mean_reward          | -1.48e+04    |
# | time/                   |              |
# |    total_timesteps      | 87000        |
# | train/                  |              |
# |    approx_kl            | 0.0017691351 |
# |    clip_fraction        | 0.0626       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 5.82e-05     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.17e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 1.77e+04     |
# ------------------------------------------
# Eval num_timesteps=88000, episode_reward=-5072.86 +/- 9760.60
# Episode length: 901.40 +/- 976.79
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 901       |
# |    mean_reward     | -5.07e+03 |
# | time/              |           |
# |    total_timesteps | 88000     |
# ----------------------------------
# Eval num_timesteps=89000, episode_reward=-325.94 +/- 1712.82
# Episode length: 426.60 +/- 170.97
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 427      |
# |    mean_reward     | -326     |
# | time/              |          |
# |    total_timesteps | 89000    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=-12853.24 +/- 18805.80
# Episode length: 1678.80 +/- 1880.52
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.68e+03  |
# |    mean_reward     | -1.29e+04 |
# | time/              |           |
# |    total_timesteps | 90000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.21e+03  |
# |    ep_rew_mean     | -1.02e+04 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 22        |
# |    time_elapsed    | 620       |
# |    total_timesteps | 90112     |
# ----------------------------------
# Eval num_timesteps=91000, episode_reward=-4217.92 +/- 6800.34
# Episode length: 815.40 +/- 681.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 815           |
# |    mean_reward          | -4.22e+03     |
# | time/                   |               |
# |    total_timesteps      | 91000         |
# | train/                  |               |
# |    approx_kl            | 0.00037489366 |
# |    clip_fraction        | 0.0138        |
# |    clip_range           | 0.1           |
# |    clip_range_vf        | 0.1           |
# |    entropy_loss         | -0.54         |
# |    explained_variance   | 0.00013       |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.13e+04      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000227     |
# |    value_loss           | 2.13e+04      |
# -------------------------------------------
# Eval num_timesteps=92000, episode_reward=-10155.30 +/- 4662.48
# Episode length: 1409.40 +/- 466.15
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.41e+03  |
# |    mean_reward     | -1.02e+04 |
# | time/              |           |
# |    total_timesteps | 92000     |
# ----------------------------------
# Eval num_timesteps=93000, episode_reward=-2306.98 +/- 5069.27
# Episode length: 624.40 +/- 506.92
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 624       |
# |    mean_reward     | -2.31e+03 |
# | time/              |           |
# |    total_timesteps | 93000     |
# ----------------------------------
# Eval num_timesteps=94000, episode_reward=-3432.98 +/- 6830.77
# Episode length: 735.40 +/- 683.97
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 735       |
# |    mean_reward     | -3.43e+03 |
# | time/              |           |
# |    total_timesteps | 94000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.14e+03  |
# |    ep_rew_mean     | -9.39e+03 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 23        |
# |    time_elapsed    | 645       |
# |    total_timesteps | 94208     |
# ----------------------------------
# Eval num_timesteps=95000, episode_reward=-14176.04 +/- 14032.23
# Episode length: 1811.20 +/- 1403.72
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.81e+03     |
# |    mean_reward          | -1.42e+04    |
# | time/                   |              |
# |    total_timesteps      | 95000        |
# | train/                  |              |
# |    approx_kl            | 0.0012967517 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 6.2e-05      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.86e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 1.96e+04     |
# ------------------------------------------
# Eval num_timesteps=96000, episode_reward=-4796.74 +/- 4392.15
# Episode length: 873.60 +/- 440.11
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 874      |
# |    mean_reward     | -4.8e+03 |
# | time/              |          |
# |    total_timesteps | 96000    |
# ---------------------------------
# Eval num_timesteps=97000, episode_reward=-11017.14 +/- 8977.89
# Episode length: 1495.60 +/- 897.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.5e+03  |
# |    mean_reward     | -1.1e+04 |
# | time/              |          |
# |    total_timesteps | 97000    |
# ---------------------------------
# Eval num_timesteps=98000, episode_reward=-2568.48 +/- 3728.16
# Episode length: 650.60 +/- 372.83
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 651       |
# |    mean_reward     | -2.57e+03 |
# | time/              |           |
# |    total_timesteps | 98000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | -9.4e+03 |
# | time/              |          |
# |    fps             | 145      |
# |    iterations      | 24       |
# |    time_elapsed    | 675      |
# |    total_timesteps | 98304    |
# ---------------------------------
# Eval num_timesteps=99000, episode_reward=-12673.32 +/- 11896.34
# Episode length: 1660.80 +/- 1190.55
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.66e+03     |
# |    mean_reward          | -1.27e+04    |
# | time/                   |              |
# |    total_timesteps      | 99000        |
# | train/                  |              |
# |    approx_kl            | 0.0014133048 |
# |    clip_fraction        | 0.0922       |
# |    clip_range           | 0.1          |
# |    clip_range_vf        | 0.1          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.00111      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.32e+04     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 2.62e+04     |
# ------------------------------------------
# Eval num_timesteps=100000, episode_reward=-11159.48 +/- 14519.64
# Episode length: 1510.80 +/- 1452.35
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.51e+03  |
# |    mean_reward     | -1.12e+04 |
# | time/              |           |
# |    total_timesteps | 100000    |
# ----------------------------------
# Eval num_timesteps=101000, episode_reward=-2193.20 +/- 2756.97
# Episode length: 613.80 +/- 274.99
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 614       |
# |    mean_reward     | -2.19e+03 |
# | time/              |           |
# |    total_timesteps | 101000    |
# ----------------------------------
# Eval num_timesteps=102000, episode_reward=1195.54 +/- 1099.09
# Episode length: 275.20 +/- 109.69
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 275      |
# |    mean_reward     | 1.2e+03  |
# | time/              |          |
# |    total_timesteps | 102000   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.15e+03  |
# |    ep_rew_mean     | -9.44e+03 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 25        |
# |    time_elapsed    | 702       |
# |    total_timesteps | 102400    |
# ----------------------------------

# %%
evaluate_model(log_path='./logs/finetune_results')

# %%
# Model testing
model_path = './logs/ppo_finetune_model/best_model.zip'
env_test = env_gym.TrafficEnvironment()
num_episodes = 200
test_model(model_path=model_path, env=env, num_episodes=num_episodes)
# Out:
# Average reward of 200 episodes is -6579.
# [-3329,
#  -16764,
#  -9239,
#  2843,
#  -11160,
#  1862,
#  -6084,
#  -7685,
#  960,
#  311,
#  2617,
#  2376,
#  -14245,
#  -7924,
#  -3289,
#  1740,
#  -509,
#  -10555,
#  -3290,
#  206,
#  323,
#  -23365,
#  -18124,
#  -31402,
#  2282,
#  2815,
#  -25,
#  1271,
#  -38029,
#  -279,
#  1858,
#  -31365,
#  2091,
#  -1094,
#  -2209,
#  2780,
#  -12830,
#  102,
#  -375,
#  2249,
#  413,
#  -36434,
#  434,
#  2183,
#  -12433,
#  -14855,
#  -1315,
#  -5605,
#  1637,
#  -8344,
#  -23060,
#  2637,
#  -14340,
#  1779,
#  -40900,
#  -2324,
#  -5135,
#  -366,
#  843,
#  -24995,
#  1888,
#  -18265,
#  -25820,
#  -7560,
#  -604,
#  435,
#  -4940,
#  1722,
#  601,
#  -4579,
#  -4895,
#  -12899,
#  -990,
#  1602,
#  -18214,
#  2020,
#  -14089,
#  -16789,
#  -33005,
#  -27750,
#  -44,
#  -7910,
#  -27305,
#  -15950,
#  2244,
#  1472,
#  -904,
#  -9188,
#  -1560,
#  2416,
#  -1750,
#  -26293,
#  -8939,
#  -5624,
#  815,
#  -20439,
#  -28508,
#  1383,
#  -3348,
#  -15318,
#  -16249,
#  42,
#  728,
#  -1397,
#  -668,
#  -32485,
#  -17970,
#  -16435,
#  -22714,
#  -6965,
#  -8570,
#  -2634,
#  156,
#  -15883,
#  -34889,
#  -44314,
#  1444,
#  1961,
#  2873,
#  -805,
#  -4038,
#  1493,
#  -6147,
#  -15309,
#  -1154,
#  1257,
#  2188,
#  -6828,
#  -4020,
#  4,
#  627,
#  864,
#  -15558,
#  1130,
#  2521,
#  -8835,
#  2120,
#  2197,
#  -6489,
#  542,
#  -7474,
#  2896,
#  290,
#  693,
#  -377,
#  -2270,
#  -387,
#  -19864,
#  1644,
#  1868,
#  -1069,
#  1845,
#  -19565,
#  -7670,
#  2636,
#  -31789,
#  1226,
#  -4635,
#  -1709,
#  -252,
#  1059,
#  2318,
#  1409,
#  -14550,
#  -2995,
#  -174,
#  -14185,
#  -12105,
#  -8704,
#  -45265,
#  1985,
#  -3288,
#  -464,
#  -5940,
#  654,
#  2056,
#  -28509,
#  2538,
#  -15049,
#  -19420,
#  2900,
#  -4669,
#  -5550,
#  1715,
#  -522,
#  1209,
#  1048,
#  1898,
#  -30054,
#  -520,
#  1386,
#  2851,
#  1843,
#  -1479,
#  2350,
#  2127,
#  -21525,
#  -6595,
#  -1489,
#  -384]
