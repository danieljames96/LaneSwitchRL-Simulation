# %%
import os
import sys
import json
from datetime import datetime

import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor

# %%
# Add the `src` folder to the Python path
sys.path.append(os.path.join(os.path.abspath('..'), 'src'))
import environment_gym as env_gym
import environment_gym_rs3 as env_gym_rs3
import utilities as util

# Load the TensorBoard extension
# %reload_ext tensorboard

# %% [markdown]
# ## Reward Shaping Method 3

# %% [markdown]
# - Remove lane swtich penalty
# - Apply reward to good lane swtich
# - Time penalty is changed from "distance covered - 10" to "2 * distance - 10"

# %% [markdown]
# ### Train Model 5

# %%
# Initialize and vectorize the environment
env = environment_gym_rs3.TrafficEnvironment(reward_shaping_flag=True)
check_env(env, warn=True)
eval_env = Monitor(environment_gym_rs3.TrafficEnvironment(reward_shaping_flag=False))

# Set up log directory
log_dir = "./logs/ppo_rs3_baseline_model/"
os.makedirs(log_dir + "best_model/", exist_ok=True)
os.makedirs(log_dir + "final_model/", exist_ok=True)

# Define the PPO model with MlpPolicy (a policy network that works well with continuous environments)
model = PPO(policy = "MlpPolicy",
            device = "cpu",    # PPO is meant to be run primarily on the CPU 
            env = env,
            verbose = 1,
            tensorboard_log = log_dir
           )

# Set up evaluation callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=log_dir + "best_model/",
    log_path=log_dir + "results/",
    eval_freq=1000,  # Evaluate the model every 1000 steps
    deterministic=True,
    render=False
)

# Train the PPO model
total_timesteps = 50000
model.learn(total_timesteps=total_timesteps, callback=eval_callback)

# Save the final model
final_model_path = log_dir + "final_model"
model.save(final_model_path)
print(f"Final model saved to {final_model_path}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/ppo_rs4_baseline_model/PPO_4
# Eval num_timesteps=1000, episode_reward=-12125.00 +/- 12262.36
# Episode length: 1604.20 +/- 1223.08
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.6e+03   |
# |    mean_reward     | -1.21e+04 |
# | time/              |           |
# |    total_timesteps | 1000      |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=-1784.00 +/- 3425.38
# Episode length: 574.00 +/- 336.64
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 574       |
# |    mean_reward     | -1.78e+03 |
# | time/              |           |
# |    total_timesteps | 2000      |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.78e+03  |
# |    ep_rew_mean     | -9.66e+03 |
# | time/              |           |
# |    fps             | 399       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 2048      |
# ----------------------------------
# Eval num_timesteps=3000, episode_reward=-18581.00 +/- 22950.65
# Episode length: 1509.40 +/- 1526.78
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.51e+03    |
# |    mean_reward          | -1.86e+04   |
# | time/                   |             |
# |    total_timesteps      | 3000        |
# | train/                  |             |
# |    approx_kl            | 0.012163922 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000141   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 2.32e+04    |
# -----------------------------------------
# Eval num_timesteps=4000, episode_reward=-11702.00 +/- 10642.14
# Episode length: 1050.80 +/- 706.29
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.05e+03  |
# |    mean_reward     | -1.17e+04 |
# | time/              |           |
# |    total_timesteps | 4000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 950       |
# |    ep_rew_mean     | -1.32e+03 |
# | time/              |           |
# |    fps             | 346       |
# |    iterations      | 2         |
# |    time_elapsed    | 11        |
# |    total_timesteps | 4096      |
# ----------------------------------
# Eval num_timesteps=5000, episode_reward=-5715.00 +/- 11380.75
# Episode length: 653.00 +/- 756.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 653          |
# |    mean_reward          | -5.72e+03    |
# | time/                   |              |
# |    total_timesteps      | 5000         |
# | train/                  |              |
# |    approx_kl            | 0.0014130181 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00196      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+04     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000584    |
# |    value_loss           | 3.73e+04     |
# ------------------------------------------
# Eval num_timesteps=6000, episode_reward=-30051.00 +/- 22046.05
# Episode length: 2271.40 +/- 1467.97
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.27e+03  |
# |    mean_reward     | -3.01e+04 |
# | time/              |           |
# |    total_timesteps | 6000      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 711      |
# |    ep_rew_mean     | 1.07e+03 |
# | time/              |          |
# |    fps             | 320      |
# |    iterations      | 3        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6144     |
# ---------------------------------
# Eval num_timesteps=7000, episode_reward=-9968.00 +/- 14738.20
# Episode length: 935.20 +/- 979.90
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 935           |
# |    mean_reward          | -9.97e+03     |
# | time/                   |               |
# |    total_timesteps      | 7000          |
# | train/                  |               |
# |    approx_kl            | 0.00083221844 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.08         |
# |    explained_variance   | 0.00696       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.1e+04       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000882     |
# |    value_loss           | 5.76e+04      |
# -------------------------------------------
# Eval num_timesteps=8000, episode_reward=-10031.00 +/- 11792.69
# Episode length: 939.40 +/- 782.93
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 939      |
# |    mean_reward     | -1e+04   |
# | time/              |          |
# |    total_timesteps | 8000     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 995       |
# |    ep_rew_mean     | -1.78e+03 |
# | time/              |           |
# |    fps             | 333       |
# |    iterations      | 4         |
# |    time_elapsed    | 24        |
# |    total_timesteps | 8192      |
# ----------------------------------
# Eval num_timesteps=9000, episode_reward=-7424.00 +/- 8548.41
# Episode length: 765.60 +/- 566.75
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 766         |
# |    mean_reward          | -7.42e+03   |
# | time/                   |             |
# |    total_timesteps      | 9000        |
# | train/                  |             |
# |    approx_kl            | 0.008129451 |
# |    clip_fraction        | 0.00464     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0308      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000436   |
# |    value_loss           | 1.45e+04    |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=-5925.00 +/- 10710.17
# Episode length: 667.00 +/- 711.37
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 667       |
# |    mean_reward     | -5.92e+03 |
# | time/              |           |
# |    total_timesteps | 10000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.02e+03  |
# |    ep_rew_mean     | -1.98e+03 |
# | time/              |           |
# |    fps             | 351       |
# |    iterations      | 5         |
# |    time_elapsed    | 29        |
# |    total_timesteps | 10240     |
# ----------------------------------
# Eval num_timesteps=11000, episode_reward=-9438.00 +/- 18592.67
# Episode length: 901.20 +/- 1236.85
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 901          |
# |    mean_reward          | -9.44e+03    |
# | time/                   |              |
# |    total_timesteps      | 11000        |
# | train/                  |              |
# |    approx_kl            | 0.0043998263 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000667     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000522    |
# |    value_loss           | 2.34e+04     |
# ------------------------------------------
# Eval num_timesteps=12000, episode_reward=-8163.00 +/- 8806.07
# Episode length: 816.20 +/- 584.42
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 816       |
# |    mean_reward     | -8.16e+03 |
# | time/              |           |
# |    total_timesteps | 12000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.01e+03  |
# |    ep_rew_mean     | -1.94e+03 |
# | time/              |           |
# |    fps             | 358       |
# |    iterations      | 6         |
# |    time_elapsed    | 34        |
# |    total_timesteps | 12288     |
# ----------------------------------
# Eval num_timesteps=13000, episode_reward=-3279.00 +/- 6769.70
# Episode length: 490.60 +/- 448.75
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 491           |
# |    mean_reward          | -3.28e+03     |
# | time/                   |               |
# |    total_timesteps      | 13000         |
# | train/                  |               |
# |    approx_kl            | 0.00055006647 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | 0.0539        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.04e+04      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000314     |
# |    value_loss           | 3.69e+04      |
# -------------------------------------------
# Eval num_timesteps=14000, episode_reward=-13317.00 +/- 25049.95
# Episode length: 1159.80 +/- 1667.35
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.16e+03  |
# |    mean_reward     | -1.33e+04 |
# | time/              |           |
# |    total_timesteps | 14000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.09e+03  |
# |    ep_rew_mean     | -2.71e+03 |
# | time/              |           |
# |    fps             | 364       |
# |    iterations      | 7         |
# |    time_elapsed    | 39        |
# |    total_timesteps | 14336     |
# ----------------------------------
# Eval num_timesteps=15000, episode_reward=-20368.00 +/- 16931.14
# Episode length: 1627.20 +/- 1125.66
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.63e+03    |
# |    mean_reward          | -2.04e+04   |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.001462522 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0585      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.17e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -1.21e-05   |
# |    value_loss           | 1.52e+04    |
# -----------------------------------------
# Eval num_timesteps=16000, episode_reward=-16187.00 +/- 17715.34
# Episode length: 1349.80 +/- 1178.03
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.35e+03  |
# |    mean_reward     | -1.62e+04 |
# | time/              |           |
# |    total_timesteps | 16000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.09e+03  |
# |    ep_rew_mean     | -2.71e+03 |
# | time/              |           |
# |    fps             | 348       |
# |    iterations      | 8         |
# |    time_elapsed    | 46        |
# |    total_timesteps | 16384     |
# ----------------------------------
# Eval num_timesteps=17000, episode_reward=-9677.00 +/- 13055.06
# Episode length: 915.80 +/- 867.10
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 916         |
# |    mean_reward          | -9.68e+03   |
# | time/                   |             |
# |    total_timesteps      | 17000       |
# | train/                  |             |
# |    approx_kl            | 0.011480022 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 1.72e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.69e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 1.87e+04    |
# -----------------------------------------
# Eval num_timesteps=18000, episode_reward=-7953.00 +/- 8382.75
# Episode length: 802.20 +/- 556.26
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 802       |
# |    mean_reward     | -7.95e+03 |
# | time/              |           |
# |    total_timesteps | 18000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.08e+03  |
# |    ep_rew_mean     | -2.66e+03 |
# | time/              |           |
# |    fps             | 353       |
# |    iterations      | 9         |
# |    time_elapsed    | 52        |
# |    total_timesteps | 18432     |
# ----------------------------------
# Eval num_timesteps=19000, episode_reward=-14672.00 +/- 15414.59
# Episode length: 1248.80 +/- 1024.46
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.25e+03    |
# |    mean_reward          | -1.47e+04   |
# | time/                   |             |
# |    total_timesteps      | 19000       |
# | train/                  |             |
# |    approx_kl            | 0.002280795 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.953      |
# |    explained_variance   | 0.0287      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.47e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0011     |
# |    value_loss           | 7.4e+04     |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=-4602.00 +/- 10223.58
# Episode length: 578.80 +/- 679.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 579      |
# |    mean_reward     | -4.6e+03 |
# | time/              |          |
# |    total_timesteps | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 888      |
# |    ep_rew_mean     | -695     |
# | time/              |          |
# |    fps             | 355      |
# |    iterations      | 10       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 20480    |
# ---------------------------------
# Eval num_timesteps=21000, episode_reward=-18664.00 +/- 16406.12
# Episode length: 1513.60 +/- 1090.77
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.51e+03      |
# |    mean_reward          | -1.87e+04     |
# | time/                   |               |
# |    total_timesteps      | 21000         |
# | train/                  |               |
# |    approx_kl            | 5.2561343e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.942        |
# |    explained_variance   | 0.133         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.5e+04       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -8.99e-05     |
# |    value_loss           | 1.05e+05      |
# -------------------------------------------
# Eval num_timesteps=22000, episode_reward=-14345.00 +/- 19349.11
# Episode length: 1227.00 +/- 1287.01
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.23e+03  |
# |    mean_reward     | -1.43e+04 |
# | time/              |           |
# |    total_timesteps | 22000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 888      |
# |    ep_rew_mean     | -695     |
# | time/              |          |
# |    fps             | 348      |
# |    iterations      | 11       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 22528    |
# ---------------------------------
# Eval num_timesteps=23000, episode_reward=-7290.00 +/- 12092.33
# Episode length: 758.00 +/- 803.54
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 758           |
# |    mean_reward          | -7.29e+03     |
# | time/                   |               |
# |    total_timesteps      | 23000         |
# | train/                  |               |
# |    approx_kl            | 0.00075180316 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.944        |
# |    explained_variance   | 0.398         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.67e+03      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00038      |
# |    value_loss           | 1.55e+04      |
# -------------------------------------------
# Eval num_timesteps=24000, episode_reward=-20677.00 +/- 16283.40
# Episode length: 1647.80 +/- 1082.88
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.65e+03  |
# |    mean_reward     | -2.07e+04 |
# | time/              |           |
# |    total_timesteps | 24000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 854      |
# |    ep_rew_mean     | -358     |
# | time/              |          |
# |    fps             | 346      |
# |    iterations      | 12       |
# |    time_elapsed    | 70       |
# |    total_timesteps | 24576    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=-5679.00 +/- 11025.82
# Episode length: 650.60 +/- 732.40
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 651          |
# |    mean_reward          | -5.68e+03    |
# | time/                   |              |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 0.0005321382 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.59e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000732    |
# |    value_loss           | 6.5e+04      |
# ------------------------------------------
# Eval num_timesteps=26000, episode_reward=-7088.00 +/- 6717.25
# Episode length: 743.20 +/- 444.92
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 743       |
# |    mean_reward     | -7.09e+03 |
# | time/              |           |
# |    total_timesteps | 26000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 854      |
# |    ep_rew_mean     | -354     |
# | time/              |          |
# |    fps             | 352      |
# |    iterations      | 13       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 26624    |
# ---------------------------------
# Eval num_timesteps=27000, episode_reward=-14368.00 +/- 16433.98
# Episode length: 1227.20 +/- 1092.94
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.23e+03     |
# |    mean_reward          | -1.44e+04    |
# | time/                   |              |
# |    total_timesteps      | 27000        |
# | train/                  |              |
# |    approx_kl            | 0.0004005146 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | 0.327        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.18e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00015     |
# |    value_loss           | 1.79e+04     |
# ------------------------------------------
# Eval num_timesteps=28000, episode_reward=-14063.00 +/- 17129.69
# Episode length: 1208.20 +/- 1138.74
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.21e+03  |
# |    mean_reward     | -1.41e+04 |
# | time/              |           |
# |    total_timesteps | 28000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 934       |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    fps             | 349       |
# |    iterations      | 14        |
# |    time_elapsed    | 82        |
# |    total_timesteps | 28672     |
# ----------------------------------
# Eval num_timesteps=29000, episode_reward=-19148.00 +/- 18142.39
# Episode length: 1547.20 +/- 1206.25
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.55e+03     |
# |    mean_reward          | -1.91e+04    |
# | time/                   |              |
# |    total_timesteps      | 29000        |
# | train/                  |              |
# |    approx_kl            | 0.0050696013 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.59e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 1.78e+04     |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=-6518.00 +/- 7481.56
# Episode length: 705.20 +/- 495.63
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 705       |
# |    mean_reward     | -6.52e+03 |
# | time/              |           |
# |    total_timesteps | 30000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 990       |
# |    ep_rew_mean     | -1.72e+03 |
# | time/              |           |
# |    fps             | 348       |
# |    iterations      | 15        |
# |    time_elapsed    | 88        |
# |    total_timesteps | 30720     |
# ----------------------------------
# Eval num_timesteps=31000, episode_reward=-12848.00 +/- 17047.20
# Episode length: 1127.20 +/- 1133.48
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.13e+03     |
# |    mean_reward          | -1.28e+04    |
# | time/                   |              |
# |    total_timesteps      | 31000        |
# | train/                  |              |
# |    approx_kl            | 0.0035066262 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.994       |
# |    explained_variance   | 0.21         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 2.16e+04     |
# ------------------------------------------
# Eval num_timesteps=32000, episode_reward=-12152.00 +/- 18355.30
# Episode length: 1080.80 +/- 1221.26
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.08e+03  |
# |    mean_reward     | -1.22e+04 |
# | time/              |           |
# |    total_timesteps | 32000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 931       |
# |    ep_rew_mean     | -1.13e+03 |
# | time/              |           |
# |    fps             | 347       |
# |    iterations      | 16        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 32768     |
# ----------------------------------
# Eval num_timesteps=33000, episode_reward=-6746.00 +/- 8968.70
# Episode length: 720.40 +/- 594.82
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 720          |
# |    mean_reward          | -6.75e+03    |
# | time/                   |              |
# |    total_timesteps      | 33000        |
# | train/                  |              |
# |    approx_kl            | 3.531773e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.38e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -9.07e-05    |
# |    value_loss           | 6.09e+04     |
# ------------------------------------------
# Eval num_timesteps=34000, episode_reward=-9512.00 +/- 14074.73
# Episode length: 904.80 +/- 935.85
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 905       |
# |    mean_reward     | -9.51e+03 |
# | time/              |           |
# |    total_timesteps | 34000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 843      |
# |    ep_rew_mean     | -248     |
# | time/              |          |
# |    fps             | 350      |
# |    iterations      | 17       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 34816    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-20957.00 +/- 21667.35
# Episode length: 1667.80 +/- 1441.30
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.67e+03      |
# |    mean_reward          | -2.1e+04      |
# | time/                   |               |
# |    total_timesteps      | 35000         |
# | train/                  |               |
# |    approx_kl            | 2.4647918e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.159         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.19e+04      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -6.4e-05      |
# |    value_loss           | 1.81e+05      |
# -------------------------------------------
# Eval num_timesteps=36000, episode_reward=-15227.00 +/- 18024.92
# Episode length: 1285.80 +/- 1198.44
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.29e+03  |
# |    mean_reward     | -1.52e+04 |
# | time/              |           |
# |    total_timesteps | 36000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 849      |
# |    ep_rew_mean     | -310     |
# | time/              |          |
# |    fps             | 345      |
# |    iterations      | 18       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 36864    |
# ---------------------------------
# Eval num_timesteps=37000, episode_reward=-364.00 +/- 1444.95
# Episode length: 297.60 +/- 96.33
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 298           |
# |    mean_reward          | -364          |
# | time/                   |               |
# |    total_timesteps      | 37000         |
# | train/                  |               |
# |    approx_kl            | 0.00041138293 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.01         |
# |    explained_variance   | 0.396         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.81e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000219     |
# |    value_loss           | 1.41e+04      |
# -------------------------------------------
# New best mean reward!
# Eval num_timesteps=38000, episode_reward=-13583.00 +/- 16858.60
# Episode length: 1176.20 +/- 1121.52
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.18e+03  |
# |    mean_reward     | -1.36e+04 |
# | time/              |           |
# |    total_timesteps | 38000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 849      |
# |    ep_rew_mean     | -310     |
# | time/              |          |
# |    fps             | 348      |
# |    iterations      | 19       |
# |    time_elapsed    | 111      |
# |    total_timesteps | 38912    |
# ---------------------------------
# Eval num_timesteps=39000, episode_reward=-7818.00 +/- 12251.76
# Episode length: 793.20 +/- 814.17
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 793         |
# |    mean_reward          | -7.82e+03   |
# | time/                   |             |
# |    total_timesteps      | 39000       |
# | train/                  |             |
# |    approx_kl            | 0.016063103 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | -0.000261   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.62e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 1.71e+04    |
# -----------------------------------------
# Eval num_timesteps=40000, episode_reward=-6843.00 +/- 11583.13
# Episode length: 728.20 +/- 769.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 728       |
# |    mean_reward     | -6.84e+03 |
# | time/              |           |
# |    total_timesteps | 40000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 895      |
# |    ep_rew_mean     | -774     |
# | time/              |          |
# |    fps             | 352      |
# |    iterations      | 20       |
# |    time_elapsed    | 116      |
# |    total_timesteps | 40960    |
# ---------------------------------
# Eval num_timesteps=41000, episode_reward=-21376.00 +/- 19613.84
# Episode length: 1694.40 +/- 1304.76
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.69e+03     |
# |    mean_reward          | -2.14e+04    |
# | time/                   |              |
# |    total_timesteps      | 41000        |
# | train/                  |              |
# |    approx_kl            | 0.0009325546 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+04     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000462    |
# |    value_loss           | 3.65e+04     |
# ------------------------------------------
# Eval num_timesteps=42000, episode_reward=-17578.00 +/- 16867.44
# Episode length: 1441.20 +/- 1121.58
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.44e+03  |
# |    mean_reward     | -1.76e+04 |
# | time/              |           |
# |    total_timesteps | 42000     |
# ----------------------------------
# Eval num_timesteps=43000, episode_reward=-10298.00 +/- 9272.30
# Episode length: 957.20 +/- 615.00
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 957       |
# |    mean_reward     | -1.03e+04 |
# | time/              |           |
# |    total_timesteps | 43000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 952       |
# |    ep_rew_mean     | -1.35e+03 |
# | time/              |           |
# |    fps             | 342       |
# |    iterations      | 21        |
# |    time_elapsed    | 125       |
# |    total_timesteps | 43008     |
# ----------------------------------
# Eval num_timesteps=44000, episode_reward=-583.00 +/- 2717.05
# Episode length: 312.20 +/- 181.14
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 312          |
# |    mean_reward          | -583         |
# | time/                   |              |
# |    total_timesteps      | 44000        |
# | train/                  |              |
# |    approx_kl            | 0.0075408043 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.376        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+04     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 2.34e+04     |
# ------------------------------------------
# Eval num_timesteps=45000, episode_reward=-18607.00 +/- 16750.61
# Episode length: 1509.80 +/- 1113.63
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.51e+03  |
# |    mean_reward     | -1.86e+04 |
# | time/              |           |
# |    total_timesteps | 45000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 914      |
# |    ep_rew_mean     | -959     |
# | time/              |          |
# |    fps             | 343      |
# |    iterations      | 22       |
# |    time_elapsed    | 131      |
# |    total_timesteps | 45056    |
# ---------------------------------
# Eval num_timesteps=46000, episode_reward=-11409.00 +/- 16812.72
# Episode length: 1032.60 +/- 1118.20
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.03e+03      |
# |    mean_reward          | -1.14e+04     |
# | time/                   |               |
# |    total_timesteps      | 46000         |
# | train/                  |               |
# |    approx_kl            | 1.0432792e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.907        |
# |    explained_variance   | 0.417         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.2e+04       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 9.29e-06      |
# |    value_loss           | 3.42e+04      |
# -------------------------------------------
# Eval num_timesteps=47000, episode_reward=-11519.00 +/- 13933.03
# Episode length: 1038.60 +/- 925.85
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.04e+03  |
# |    mean_reward     | -1.15e+04 |
# | time/              |           |
# |    total_timesteps | 47000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 888      |
# |    ep_rew_mean     | -706     |
# | time/              |          |
# |    fps             | 343      |
# |    iterations      | 23       |
# |    time_elapsed    | 136      |
# |    total_timesteps | 47104    |
# ---------------------------------
# Eval num_timesteps=48000, episode_reward=-10841.00 +/- 12322.22
# Episode length: 993.40 +/- 818.32
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 993           |
# |    mean_reward          | -1.08e+04     |
# | time/                   |               |
# |    total_timesteps      | 48000         |
# | train/                  |               |
# |    approx_kl            | 0.00032177716 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.912        |
# |    explained_variance   | 0.369         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.33e+04      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000416     |
# |    value_loss           | 3.84e+04      |
# -------------------------------------------
# Eval num_timesteps=49000, episode_reward=-12848.00 +/- 14584.53
# Episode length: 1127.20 +/- 969.28
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.13e+03  |
# |    mean_reward     | -1.28e+04 |
# | time/              |           |
# |    total_timesteps | 49000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 943       |
# |    ep_rew_mean     | -1.25e+03 |
# | time/              |           |
# |    fps             | 344       |
# |    iterations      | 24        |
# |    time_elapsed    | 142       |
# |    total_timesteps | 49152     |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-1060.00 +/- 1960.59
# Episode length: 344.00 +/- 130.71
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 344        |
# |    mean_reward          | -1.06e+03  |
# | time/                   |            |
# |    total_timesteps      | 50000      |
# | train/                  |            |
# |    approx_kl            | 0.00508147 |
# |    clip_fraction        | 0.0438     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.93      |
# |    explained_variance   | 0.466      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.64e+03   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0021    |
# |    value_loss           | 1.96e+04   |
# ----------------------------------------
# Eval num_timesteps=51000, episode_reward=-9344.00 +/- 11060.01
# Episode length: 893.60 +/- 734.39
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 894       |
# |    mean_reward     | -9.34e+03 |
# | time/              |           |
# |    total_timesteps | 51000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 940       |
# |    ep_rew_mean     | -1.22e+03 |
# | time/              |           |
# |    fps             | 348       |
# |    iterations      | 25        |
# |    time_elapsed    | 147       |
# |    total_timesteps | 51200     |
# ----------------------------------
# Final model saved to ./logs/ppo_rs4_baseline_model/final_model

# %% [markdown]
# ### Test Model 5

# %%
# Load the best baseline model
log_dir = "./logs/ppo_rs3_baseline_model/"
model_path = log_dir + 'best_model/best_model.zip'
model = PPO.load(model_path)

# Create test environment
env_test = env_gym.TrafficEnvironment()

# %%
# Test the model
num_episodes = 1000
file_name = 'ppo_rs3_best_model_test_log.json'
rewards, timesteps = util.test_model(model=model, env=env_test, num_episodes=num_episodes, output_file=file_name)

# %% [markdown]
# ### Analysis of Model 5

# %%
util.plot_test_dotplots(rewards=rewards, timesteps=timesteps, interval=100)
# Out:
# Average reward of 1000 episodes is -12590.
# Average timesteps of 1000 episodes is 1110.

# %%
util.plot_test_boxplots(json_file=file_name)

# %%
util.calculate_action_percentages(log_file=file_name)
print("")
util.calculate_clearance_rate_percentages(log_file=file_name)
# Out:
# Total actions across 1000 episodes: 1109869
# Action -1: 0.0%
# Action 0: 0.0%
# Action 1: 100.0%
#
# Total timesteps across 1000 episodes (including initial states): 1110869
# Lane 1:
#   78.6% of timesteps had a clearance rate less than 5
#   88.1% of timesteps had a clearance rate less than 10
# Lane 2:
#   78.4% of timesteps had a clearance rate less than 5
#   88.2% of timesteps had a clearance rate less than 10
# Lane 3:
#   78.4% of timesteps had a clearance rate less than 5
#   88.4% of timesteps had a clearance rate less than 10
# Lane 4:
#   78.7% of timesteps had a clearance rate less than 5
#   88.8% of timesteps had a clearance rate less than 10
# Lane 5:
#   79.1% of timesteps had a clearance rate less than 5
#   89.0% of timesteps had a clearance rate less than 10

# %% [markdown]
# ### Train Model 6 (Fine-tune Model 5)

# %%
# Initialize and vectorize the environment
env = env_gym_rs3.TrafficEnvironment(reward_shaping_flag=True)
check_env(env, warn=True)
eval_env = Monitor(env_gym_rs3.TrafficEnvironment(reward_shaping_flag=False))

# Set up log directory
log_dir = "./logs/ppo_rs3_finetune_model/"
os.makedirs(log_dir + "best_model/", exist_ok=True)
os.makedirs(log_dir + "final_model/", exist_ok=True)

# Define the PPO model with MlpPolicy (a policy network that works well with continuous environments)
model = PPO(policy = "MlpPolicy",
            device = "cpu",    # PPO is meant to be run primarily on the CPU 
            env = env,
            learning_rate=0.0005,
            ent_coef=0.1,
            clip_range=0.3,
            n_steps=4096,
            batch_size=256,
            gamma=0.3,
            verbose = 1,
            tensorboard_log = log_dir
           )

# Set up evaluation callback
eval_callback = EvalCallback(
    eval_env,
    best_model_save_path=log_dir + "best_model/",
    log_path=log_dir + "results/",
    eval_freq=1000,  # Evaluate the model every 1000 steps
    deterministic=False,
    render=False
)

# Train the PPO model
total_timesteps = 100000
model.learn(total_timesteps=total_timesteps, callback=eval_callback)

# Save the final model
final_model_path = log_dir + "final_model"
model.save(final_model_path)
print(f"Final model saved to {final_model_path}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/ppo_rs4_finetune_model/PPO_4
# Eval num_timesteps=1000, episode_reward=-13321.00 +/- 15973.50
# Episode length: 1305.60 +/- 1197.20
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.31e+03  |
# |    mean_reward     | -1.33e+04 |
# | time/              |           |
# |    total_timesteps | 1000      |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=-2744.00 +/- 3895.73
# Episode length: 510.60 +/- 288.81
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 511       |
# |    mean_reward     | -2.74e+03 |
# | time/              |           |
# |    total_timesteps | 2000      |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=3000, episode_reward=-15065.00 +/- 17470.41
# Episode length: 1434.40 +/- 1305.64
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.43e+03  |
# |    mean_reward     | -1.51e+04 |
# | time/              |           |
# |    total_timesteps | 3000      |
# ----------------------------------
# Eval num_timesteps=4000, episode_reward=147.00 +/- 1546.16
# Episode length: 298.00 +/- 115.88
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 298      |
# |    mean_reward     | 147      |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.27e+03  |
# |    ep_rew_mean     | -4.52e+03 |
# | time/              |           |
# |    fps             | 174       |
# |    iterations      | 1         |
# |    time_elapsed    | 23        |
# |    total_timesteps | 4096      |
# ----------------------------------
# Eval num_timesteps=5000, episode_reward=-9964.00 +/- 13020.11
# Episode length: 1030.80 +/- 950.35
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.03e+03    |
# |    mean_reward          | -9.96e+03   |
# | time/                   |             |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.017073665 |
# |    clip_fraction        | 0.00022     |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00143    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 215         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 543         |
# -----------------------------------------
# Eval num_timesteps=6000, episode_reward=-3207.00 +/- 4674.82
# Episode length: 535.40 +/- 340.47
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 535       |
# |    mean_reward     | -3.21e+03 |
# | time/              |           |
# |    total_timesteps | 6000      |
# ----------------------------------
# Eval num_timesteps=7000, episode_reward=-129.00 +/- 1524.42
# Episode length: 311.40 +/- 111.72
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 311      |
# |    mean_reward     | -129     |
# | time/              |          |
# |    total_timesteps | 7000     |
# ---------------------------------
# Eval num_timesteps=8000, episode_reward=-13483.00 +/- 14254.53
# Episode length: 1290.40 +/- 1047.00
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.29e+03  |
# |    mean_reward     | -1.35e+04 |
# | time/              |           |
# |    total_timesteps | 8000      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.35e+03  |
# |    ep_rew_mean     | -5.37e+03 |
# | time/              |           |
# |    fps             | 179       |
# |    iterations      | 2         |
# |    time_elapsed    | 45        |
# |    total_timesteps | 8192      |
# ----------------------------------
# Eval num_timesteps=9000, episode_reward=-22906.00 +/- 17577.37
# Episode length: 2016.80 +/- 1309.56
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2.02e+03    |
# |    mean_reward          | -2.29e+04   |
# | time/                   |             |
# |    total_timesteps      | 9000        |
# | train/                  |             |
# |    approx_kl            | 0.032558404 |
# |    clip_fraction        | 0.00872     |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 57          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 177         |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=-4255.00 +/- 8006.13
# Episode length: 622.00 +/- 596.81
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 622       |
# |    mean_reward     | -4.26e+03 |
# | time/              |           |
# |    total_timesteps | 10000     |
# ----------------------------------
# Eval num_timesteps=11000, episode_reward=-15277.00 +/- 17388.57
# Episode length: 1442.60 +/- 1293.52
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.44e+03  |
# |    mean_reward     | -1.53e+04 |
# | time/              |           |
# |    total_timesteps | 11000     |
# ----------------------------------
# Eval num_timesteps=12000, episode_reward=-8598.00 +/- 7363.70
# Episode length: 943.00 +/- 545.25
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 943      |
# |    mean_reward     | -8.6e+03 |
# | time/              |          |
# |    total_timesteps | 12000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.41e+03  |
# |    ep_rew_mean     | -5.98e+03 |
# | time/              |           |
# |    fps             | 158       |
# |    iterations      | 3         |
# |    time_elapsed    | 77        |
# |    total_timesteps | 12288     |
# ----------------------------------
# Eval num_timesteps=13000, episode_reward=-10741.00 +/- 12929.97
# Episode length: 1085.20 +/- 943.03
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.09e+03    |
# |    mean_reward          | -1.07e+04   |
# | time/                   |             |
# |    total_timesteps      | 13000       |
# | train/                  |             |
# |    approx_kl            | 0.005209244 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 7           |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000765   |
# |    value_loss           | 17.2        |
# -----------------------------------------
# Eval num_timesteps=14000, episode_reward=-22940.00 +/- 14870.44
# Episode length: 1983.60 +/- 1092.81
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.98e+03  |
# |    mean_reward     | -2.29e+04 |
# | time/              |           |
# |    total_timesteps | 14000     |
# ----------------------------------
# Eval num_timesteps=15000, episode_reward=-18354.00 +/- 15483.08
# Episode length: 1650.00 +/- 1139.94
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.65e+03  |
# |    mean_reward     | -1.84e+04 |
# | time/              |           |
# |    total_timesteps | 15000     |
# ----------------------------------
# Eval num_timesteps=16000, episode_reward=-1033.00 +/- 811.37
# Episode length: 377.40 +/- 60.42
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 377       |
# |    mean_reward     | -1.03e+03 |
# | time/              |           |
# |    total_timesteps | 16000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.32e+03  |
# |    ep_rew_mean     | -5.05e+03 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 4         |
# |    time_elapsed    | 109       |
# |    total_timesteps | 16384     |
# ----------------------------------
# Eval num_timesteps=17000, episode_reward=-4113.00 +/- 9254.68
# Episode length: 604.60 +/- 681.01
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 605         |
# |    mean_reward          | -4.11e+03   |
# | time/                   |             |
# |    total_timesteps      | 17000       |
# | train/                  |             |
# |    approx_kl            | 0.006638362 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 154         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 384         |
# -----------------------------------------
# Eval num_timesteps=18000, episode_reward=-4576.00 +/- 9189.94
# Episode length: 642.20 +/- 679.25
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 642       |
# |    mean_reward     | -4.58e+03 |
# | time/              |           |
# |    total_timesteps | 18000     |
# ----------------------------------
# Eval num_timesteps=19000, episode_reward=-15328.00 +/- 15169.38
# Episode length: 1431.60 +/- 1122.81
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.43e+03  |
# |    mean_reward     | -1.53e+04 |
# | time/              |           |
# |    total_timesteps | 19000     |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=-13564.00 +/- 18301.57
# Episode length: 1305.00 +/- 1347.38
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.3e+03   |
# |    mean_reward     | -1.36e+04 |
# | time/              |           |
# |    total_timesteps | 20000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.11e+03  |
# |    ep_rew_mean     | -2.98e+03 |
# | time/              |           |
# |    fps             | 150       |
# |    iterations      | 5         |
# |    time_elapsed    | 135       |
# |    total_timesteps | 20480     |
# ----------------------------------
# Eval num_timesteps=21000, episode_reward=-20937.00 +/- 10225.74
# Episode length: 1877.00 +/- 774.11
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.88e+03    |
# |    mean_reward          | -2.09e+04   |
# | time/                   |             |
# |    total_timesteps      | 21000       |
# | train/                  |             |
# |    approx_kl            | 0.031590004 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 72.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 213         |
# -----------------------------------------
# Eval num_timesteps=22000, episode_reward=-24548.00 +/- 18535.00
# Episode length: 2157.40 +/- 1404.63
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.16e+03  |
# |    mean_reward     | -2.45e+04 |
# | time/              |           |
# |    total_timesteps | 22000     |
# ----------------------------------
# Eval num_timesteps=23000, episode_reward=-8039.00 +/- 17187.26
# Episode length: 911.40 +/- 1288.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 911       |
# |    mean_reward     | -8.04e+03 |
# | time/              |           |
# |    total_timesteps | 23000     |
# ----------------------------------
# Eval num_timesteps=24000, episode_reward=-9166.00 +/- 8482.29
# Episode length: 1001.40 +/- 642.08
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1e+03     |
# |    mean_reward     | -9.17e+03 |
# | time/              |           |
# |    total_timesteps | 24000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.04e+03  |
# |    ep_rew_mean     | -2.18e+03 |
# | time/              |           |
# |    fps             | 142       |
# |    iterations      | 6         |
# |    time_elapsed    | 172       |
# |    total_timesteps | 24576     |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=-8595.00 +/- 8269.60
# Episode length: 942.40 +/- 613.16
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 942        |
# |    mean_reward          | -8.6e+03   |
# | time/                   |            |
# |    total_timesteps      | 25000      |
# | train/                  |            |
# |    approx_kl            | 0.00921483 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.3        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.605      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 59.1       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0023    |
# |    value_loss           | 140        |
# ----------------------------------------
# Eval num_timesteps=26000, episode_reward=-15821.00 +/- 14428.31
# Episode length: 1480.00 +/- 1069.88
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.48e+03  |
# |    mean_reward     | -1.58e+04 |
# | time/              |           |
# |    total_timesteps | 26000     |
# ----------------------------------
# Eval num_timesteps=27000, episode_reward=-3263.00 +/- 3579.66
# Episode length: 542.80 +/- 260.99
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 543       |
# |    mean_reward     | -3.26e+03 |
# | time/              |           |
# |    total_timesteps | 27000     |
# ----------------------------------
# Eval num_timesteps=28000, episode_reward=375.00 +/- 916.82
# Episode length: 278.80 +/- 68.05
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 279      |
# |    mean_reward     | 375      |
# | time/              |          |
# |    total_timesteps | 28000    |
# ---------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.06e+03  |
# |    ep_rew_mean     | -2.46e+03 |
# | time/              |           |
# |    fps             | 146       |
# |    iterations      | 7         |
# |    time_elapsed    | 195       |
# |    total_timesteps | 28672     |
# ----------------------------------
# Eval num_timesteps=29000, episode_reward=-17459.00 +/- 21767.90
# Episode length: 1617.00 +/- 1639.70
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.62e+03     |
# |    mean_reward          | -1.75e+04    |
# | time/                   |              |
# |    total_timesteps      | 29000        |
# | train/                  |              |
# |    approx_kl            | 0.0018536153 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 25           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000139    |
# |    value_loss           | 174          |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=-14911.00 +/- 14436.85
# Episode length: 1418.80 +/- 1075.43
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.42e+03  |
# |    mean_reward     | -1.49e+04 |
# | time/              |           |
# |    total_timesteps | 30000     |
# ----------------------------------
# Eval num_timesteps=31000, episode_reward=-5434.00 +/- 7753.81
# Episode length: 710.80 +/- 577.50
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 711       |
# |    mean_reward     | -5.43e+03 |
# | time/              |           |
# |    total_timesteps | 31000     |
# ----------------------------------
# Eval num_timesteps=32000, episode_reward=-26348.00 +/- 14181.40
# Episode length: 2279.60 +/- 1062.50
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 2.28e+03  |
# |    mean_reward     | -2.63e+04 |
# | time/              |           |
# |    total_timesteps | 32000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 954       |
# |    ep_rew_mean     | -1.36e+03 |
# | time/              |           |
# |    fps             | 141       |
# |    iterations      | 8         |
# |    time_elapsed    | 232       |
# |    total_timesteps | 32768     |
# ----------------------------------
# Eval num_timesteps=33000, episode_reward=-5560.00 +/- 3511.05
# Episode length: 712.40 +/- 259.12
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 712         |
# |    mean_reward          | -5.56e+03   |
# | time/                   |             |
# |    total_timesteps      | 33000       |
# | train/                  |             |
# |    approx_kl            | 0.011623794 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 142         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00242    |
# |    value_loss           | 489         |
# -----------------------------------------
# Eval num_timesteps=34000, episode_reward=-3323.00 +/- 6168.55
# Episode length: 552.00 +/- 459.35
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 552       |
# |    mean_reward     | -3.32e+03 |
# | time/              |           |
# |    total_timesteps | 34000     |
# ----------------------------------
# Eval num_timesteps=35000, episode_reward=-11405.00 +/- 14026.67
# Episode length: 1150.40 +/- 1042.66
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.15e+03  |
# |    mean_reward     | -1.14e+04 |
# | time/              |           |
# |    total_timesteps | 35000     |
# ----------------------------------
# Eval num_timesteps=36000, episode_reward=-3801.00 +/- 4584.11
# Episode length: 584.40 +/- 334.95
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 584      |
# |    mean_reward     | -3.8e+03 |
# | time/              |          |
# |    total_timesteps | 36000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.02e+03  |
# |    ep_rew_mean     | -2.04e+03 |
# | time/              |           |
# |    fps             | 145       |
# |    iterations      | 9         |
# |    time_elapsed    | 253       |
# |    total_timesteps | 36864     |
# ----------------------------------
# Eval num_timesteps=37000, episode_reward=-4807.00 +/- 9153.23
# Episode length: 655.40 +/- 672.96
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 655          |
# |    mean_reward          | -4.81e+03    |
# | time/                   |              |
# |    total_timesteps      | 37000        |
# | train/                  |              |
# |    approx_kl            | 0.0035280092 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.717        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 15.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00095     |
# |    value_loss           | 21.5         |
# ------------------------------------------
# Eval num_timesteps=38000, episode_reward=901.00 +/- 580.37
# Episode length: 236.40 +/- 43.12
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 236      |
# |    mean_reward     | 901      |
# | time/              |          |
# |    total_timesteps | 38000    |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=39000, episode_reward=-3622.00 +/- 5643.22
# Episode length: 566.00 +/- 412.29
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 566       |
# |    mean_reward     | -3.62e+03 |
# | time/              |           |
# |    total_timesteps | 39000     |
# ----------------------------------
# Eval num_timesteps=40000, episode_reward=-11529.00 +/- 13277.00
# Episode length: 1154.00 +/- 983.15
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.15e+03  |
# |    mean_reward     | -1.15e+04 |
# | time/              |           |
# |    total_timesteps | 40000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 997      |
# |    ep_rew_mean     | -1.8e+03 |
# | time/              |          |
# |    fps             | 149      |
# |    iterations      | 10       |
# |    time_elapsed    | 273      |
# |    total_timesteps | 40960    |
# ---------------------------------
# Eval num_timesteps=41000, episode_reward=-19548.00 +/- 16409.39
# Episode length: 1743.20 +/- 1213.44
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.74e+03    |
# |    mean_reward          | -1.95e+04   |
# | time/                   |             |
# |    total_timesteps      | 41000       |
# | train/                  |             |
# |    approx_kl            | 0.021245359 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 95.7        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 213         |
# -----------------------------------------
# Eval num_timesteps=42000, episode_reward=-19209.00 +/- 18951.93
# Episode length: 1708.60 +/- 1391.60
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.71e+03  |
# |    mean_reward     | -1.92e+04 |
# | time/              |           |
# |    total_timesteps | 42000     |
# ----------------------------------
# Eval num_timesteps=43000, episode_reward=-161.00 +/- 2072.70
# Episode length: 315.60 +/- 152.73
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 316      |
# |    mean_reward     | -161     |
# | time/              |          |
# |    total_timesteps | 43000    |
# ---------------------------------
# Eval num_timesteps=44000, episode_reward=-469.00 +/- 2200.02
# Episode length: 337.80 +/- 161.25
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 338      |
# |    mean_reward     | -469     |
# | time/              |          |
# |    total_timesteps | 44000    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=-6726.00 +/- 6847.53
# Episode length: 796.00 +/- 500.95
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 796       |
# |    mean_reward     | -6.73e+03 |
# | time/              |           |
# |    total_timesteps | 45000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 998      |
# |    ep_rew_mean     | -1.8e+03 |
# | time/              |          |
# |    fps             | 148      |
# |    iterations      | 11       |
# |    time_elapsed    | 304      |
# |    total_timesteps | 45056    |
# ---------------------------------
# Eval num_timesteps=46000, episode_reward=-2782.00 +/- 5721.36
# Episode length: 506.20 +/- 420.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 506          |
# |    mean_reward          | -2.78e+03    |
# | time/                   |              |
# |    total_timesteps      | 46000        |
# | train/                  |              |
# |    approx_kl            | 0.0050023906 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.634        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 24.3         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000767    |
# |    value_loss           | 91.1         |
# ------------------------------------------
# Eval num_timesteps=47000, episode_reward=-3550.00 +/- 8770.84
# Episode length: 563.60 +/- 639.57
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 564       |
# |    mean_reward     | -3.55e+03 |
# | time/              |           |
# |    total_timesteps | 47000     |
# ----------------------------------
# Eval num_timesteps=48000, episode_reward=-9009.00 +/- 8251.17
# Episode length: 967.20 +/- 609.96
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 967       |
# |    mean_reward     | -9.01e+03 |
# | time/              |           |
# |    total_timesteps | 48000     |
# ----------------------------------
# Eval num_timesteps=49000, episode_reward=-9092.00 +/- 8120.42
# Episode length: 976.00 +/- 600.01
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 976       |
# |    mean_reward     | -9.09e+03 |
# | time/              |           |
# |    total_timesteps | 49000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 980       |
# |    ep_rew_mean     | -1.62e+03 |
# | time/              |           |
# |    fps             | 150       |
# |    iterations      | 12        |
# |    time_elapsed    | 325       |
# |    total_timesteps | 49152     |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=-7279.00 +/- 14522.90
# Episode length: 827.40 +/- 1053.50
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 827          |
# |    mean_reward          | -7.28e+03    |
# | time/                   |              |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0038531432 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 42.3         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 77.1         |
# ------------------------------------------
# Eval num_timesteps=51000, episode_reward=-13869.00 +/- 16590.92
# Episode length: 1308.20 +/- 1212.14
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.31e+03  |
# |    mean_reward     | -1.39e+04 |
# | time/              |           |
# |    total_timesteps | 51000     |
# ----------------------------------
# Eval num_timesteps=52000, episode_reward=-15021.00 +/- 18363.65
# Episode length: 1389.00 +/- 1332.61
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.39e+03 |
# |    mean_reward     | -1.5e+04 |
# | time/              |          |
# |    total_timesteps | 52000    |
# ---------------------------------
# Eval num_timesteps=53000, episode_reward=-12619.00 +/- 15636.32
# Episode length: 1214.60 +/- 1129.91
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.21e+03  |
# |    mean_reward     | -1.26e+04 |
# | time/              |           |
# |    total_timesteps | 53000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 993       |
# |    ep_rew_mean     | -1.75e+03 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 13        |
# |    time_elapsed    | 355       |
# |    total_timesteps | 53248     |
# ----------------------------------
# Eval num_timesteps=54000, episode_reward=-10771.00 +/- 13208.13
# Episode length: 1083.60 +/- 962.74
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.08e+03    |
# |    mean_reward          | -1.08e+04   |
# | time/                   |             |
# |    total_timesteps      | 54000       |
# | train/                  |             |
# |    approx_kl            | 0.030477623 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 14          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 38.7        |
# -----------------------------------------
# Eval num_timesteps=55000, episode_reward=-22114.00 +/- 23164.08
# Episode length: 1920.20 +/- 1702.87
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.92e+03  |
# |    mean_reward     | -2.21e+04 |
# | time/              |           |
# |    total_timesteps | 55000     |
# ----------------------------------
# Eval num_timesteps=56000, episode_reward=140.00 +/- 1080.87
# Episode length: 291.00 +/- 77.86
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 291      |
# |    mean_reward     | 140      |
# | time/              |          |
# |    total_timesteps | 56000    |
# ---------------------------------
# Eval num_timesteps=57000, episode_reward=-2661.00 +/- 5497.55
# Episode length: 491.80 +/- 398.87
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 492       |
# |    mean_reward     | -2.66e+03 |
# | time/              |           |
# |    total_timesteps | 57000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.02e+03  |
# |    ep_rew_mean     | -2.01e+03 |
# | time/              |           |
# |    fps             | 150       |
# |    iterations      | 14        |
# |    time_elapsed    | 381       |
# |    total_timesteps | 57344     |
# ----------------------------------
# Eval num_timesteps=58000, episode_reward=-6305.00 +/- 6599.97
# Episode length: 755.60 +/- 478.80
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 756          |
# |    mean_reward          | -6.3e+03     |
# | time/                   |              |
# |    total_timesteps      | 58000        |
# | train/                  |              |
# |    approx_kl            | 0.0023803911 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 245          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.000633     |
# |    value_loss           | 325          |
# ------------------------------------------
# Eval num_timesteps=59000, episode_reward=-10777.00 +/- 18531.86
# Episode length: 1084.40 +/- 1354.46
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.08e+03  |
# |    mean_reward     | -1.08e+04 |
# | time/              |           |
# |    total_timesteps | 59000     |
# ----------------------------------
# Eval num_timesteps=60000, episode_reward=-10319.00 +/- 15292.52
# Episode length: 1050.80 +/- 1116.04
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.05e+03  |
# |    mean_reward     | -1.03e+04 |
# | time/              |           |
# |    total_timesteps | 60000     |
# ----------------------------------
# Eval num_timesteps=61000, episode_reward=-11384.00 +/- 12573.13
# Episode length: 1128.80 +/- 917.91
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.13e+03  |
# |    mean_reward     | -1.14e+04 |
# | time/              |           |
# |    total_timesteps | 61000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.02e+03  |
# |    ep_rew_mean     | -2.02e+03 |
# | time/              |           |
# |    fps             | 150       |
# |    iterations      | 15        |
# |    time_elapsed    | 407       |
# |    total_timesteps | 61440     |
# ----------------------------------
# Eval num_timesteps=62000, episode_reward=-2378.00 +/- 8070.82
# Episode length: 483.80 +/- 600.41
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 484        |
# |    mean_reward          | -2.38e+03  |
# | time/                   |            |
# |    total_timesteps      | 62000      |
# | train/                  |            |
# |    approx_kl            | 0.03437027 |
# |    clip_fraction        | 0.00686    |
# |    clip_range           | 0.3        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.683      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 96.4       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.00614   |
# |    value_loss           | 128        |
# ----------------------------------------
# Eval num_timesteps=63000, episode_reward=-7934.00 +/- 10529.81
# Episode length: 898.80 +/- 786.35
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 899       |
# |    mean_reward     | -7.93e+03 |
# | time/              |           |
# |    total_timesteps | 63000     |
# ----------------------------------
# Eval num_timesteps=64000, episode_reward=-2735.00 +/- 5281.18
# Episode length: 511.00 +/- 394.03
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 511       |
# |    mean_reward     | -2.74e+03 |
# | time/              |           |
# |    total_timesteps | 64000     |
# ----------------------------------
# Eval num_timesteps=65000, episode_reward=-4946.00 +/- 8975.97
# Episode length: 680.80 +/- 673.79
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 681       |
# |    mean_reward     | -4.95e+03 |
# | time/              |           |
# |    total_timesteps | 65000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 988      |
# |    ep_rew_mean     | -1.7e+03 |
# | time/              |          |
# |    fps             | 153      |
# |    iterations      | 16       |
# |    time_elapsed    | 427      |
# |    total_timesteps | 65536    |
# ---------------------------------
# Eval num_timesteps=66000, episode_reward=-17993.00 +/- 15267.98
# Episode length: 1665.60 +/- 1150.70
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.67e+03    |
# |    mean_reward          | -1.8e+04    |
# | time/                   |             |
# |    total_timesteps      | 66000       |
# | train/                  |             |
# |    approx_kl            | 0.025226636 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 21.5        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00897    |
# |    value_loss           | 86.1        |
# -----------------------------------------
# Eval num_timesteps=67000, episode_reward=-5489.00 +/- 8043.12
# Episode length: 718.80 +/- 601.29
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 719       |
# |    mean_reward     | -5.49e+03 |
# | time/              |           |
# |    total_timesteps | 67000     |
# ----------------------------------
# Eval num_timesteps=68000, episode_reward=-14240.00 +/- 13394.61
# Episode length: 1378.80 +/- 1010.12
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.38e+03  |
# |    mean_reward     | -1.42e+04 |
# | time/              |           |
# |    total_timesteps | 68000     |
# ----------------------------------
# Eval num_timesteps=69000, episode_reward=-5725.00 +/- 12719.71
# Episode length: 740.40 +/- 960.24
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 740       |
# |    mean_reward     | -5.72e+03 |
# | time/              |           |
# |    total_timesteps | 69000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 994       |
# |    ep_rew_mean     | -1.77e+03 |
# | time/              |           |
# |    fps             | 152       |
# |    iterations      | 17        |
# |    time_elapsed    | 456       |
# |    total_timesteps | 69632     |
# ----------------------------------
# Eval num_timesteps=70000, episode_reward=-26358.00 +/- 13510.70
# Episode length: 2268.40 +/- 1011.76
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2.27e+03     |
# |    mean_reward          | -2.64e+04    |
# | time/                   |              |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0078102807 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 52.6         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 130          |
# ------------------------------------------
# Eval num_timesteps=71000, episode_reward=-2597.00 +/- 4153.68
# Episode length: 501.60 +/- 310.67
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 502      |
# |    mean_reward     | -2.6e+03 |
# | time/              |          |
# |    total_timesteps | 71000    |
# ---------------------------------
# Eval num_timesteps=72000, episode_reward=-20151.00 +/- 16147.17
# Episode length: 1807.20 +/- 1203.22
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.81e+03  |
# |    mean_reward     | -2.02e+04 |
# | time/              |           |
# |    total_timesteps | 72000     |
# ----------------------------------
# Eval num_timesteps=73000, episode_reward=-5371.00 +/- 9492.89
# Episode length: 707.00 +/- 706.76
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 707       |
# |    mean_reward     | -5.37e+03 |
# | time/              |           |
# |    total_timesteps | 73000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 979       |
# |    ep_rew_mean     | -1.61e+03 |
# | time/              |           |
# |    fps             | 150       |
# |    iterations      | 18        |
# |    time_elapsed    | 489       |
# |    total_timesteps | 73728     |
# ----------------------------------
# Eval num_timesteps=74000, episode_reward=-11235.00 +/- 14910.96
# Episode length: 1153.60 +/- 1122.65
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.15e+03    |
# |    mean_reward          | -1.12e+04   |
# | time/                   |             |
# |    total_timesteps      | 74000       |
# | train/                  |             |
# |    approx_kl            | 0.015784342 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 76.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 144         |
# -----------------------------------------
# Eval num_timesteps=75000, episode_reward=-6083.00 +/- 5077.64
# Episode length: 761.40 +/- 382.19
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 761       |
# |    mean_reward     | -6.08e+03 |
# | time/              |           |
# |    total_timesteps | 75000     |
# ----------------------------------
# Eval num_timesteps=76000, episode_reward=-19836.00 +/- 18419.56
# Episode length: 1801.20 +/- 1385.69
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.8e+03   |
# |    mean_reward     | -1.98e+04 |
# | time/              |           |
# |    total_timesteps | 76000     |
# ----------------------------------
# Eval num_timesteps=77000, episode_reward=-9028.00 +/- 9030.03
# Episode length: 987.20 +/- 676.45
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 987       |
# |    mean_reward     | -9.03e+03 |
# | time/              |           |
# |    total_timesteps | 77000     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 909      |
# |    ep_rew_mean     | -905     |
# | time/              |          |
# |    fps             | 149      |
# |    iterations      | 19       |
# |    time_elapsed    | 519      |
# |    total_timesteps | 77824    |
# ---------------------------------
# Eval num_timesteps=78000, episode_reward=-9490.00 +/- 19506.13
# Episode length: 1009.20 +/- 1446.12
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.01e+03     |
# |    mean_reward          | -9.49e+03    |
# | time/                   |              |
# |    total_timesteps      | 78000        |
# | train/                  |              |
# |    approx_kl            | 0.0035091802 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 167          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 260          |
# ------------------------------------------
# Eval num_timesteps=79000, episode_reward=-15711.00 +/- 12644.29
# Episode length: 1475.60 +/- 941.16
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.48e+03  |
# |    mean_reward     | -1.57e+04 |
# | time/              |           |
# |    total_timesteps | 79000     |
# ----------------------------------
# Eval num_timesteps=80000, episode_reward=-13176.00 +/- 11881.62
# Episode length: 1285.80 +/- 884.91
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.29e+03  |
# |    mean_reward     | -1.32e+04 |
# | time/              |           |
# |    total_timesteps | 80000     |
# ----------------------------------
# Eval num_timesteps=81000, episode_reward=-4998.00 +/- 6113.19
# Episode length: 677.20 +/- 452.32
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 677      |
# |    mean_reward     | -5e+03   |
# | time/              |          |
# |    total_timesteps | 81000    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 925       |
# |    ep_rew_mean     | -1.07e+03 |
# | time/              |           |
# |    fps             | 149       |
# |    iterations      | 20        |
# |    time_elapsed    | 547       |
# |    total_timesteps | 81920     |
# ----------------------------------
# Eval num_timesteps=82000, episode_reward=-3829.00 +/- 4472.10
# Episode length: 583.80 +/- 327.93
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 584         |
# |    mean_reward          | -3.83e+03   |
# | time/                   |             |
# |    total_timesteps      | 82000       |
# | train/                  |             |
# |    approx_kl            | 0.018500157 |
# |    clip_fraction        | 0.0189      |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 71.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0036     |
# |    value_loss           | 65.1        |
# -----------------------------------------
# Eval num_timesteps=83000, episode_reward=-7826.00 +/- 12661.20
# Episode length: 881.20 +/- 932.50
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 881       |
# |    mean_reward     | -7.83e+03 |
# | time/              |           |
# |    total_timesteps | 83000     |
# ----------------------------------
# Eval num_timesteps=84000, episode_reward=-1459.00 +/- 4292.27
# Episode length: 410.20 +/- 315.36
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 410       |
# |    mean_reward     | -1.46e+03 |
# | time/              |           |
# |    total_timesteps | 84000     |
# ----------------------------------
# Eval num_timesteps=85000, episode_reward=-18483.00 +/- 12525.46
# Episode length: 1665.80 +/- 924.32
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.67e+03  |
# |    mean_reward     | -1.85e+04 |
# | time/              |           |
# |    total_timesteps | 85000     |
# ----------------------------------
# Eval num_timesteps=86000, episode_reward=-14657.00 +/- 17856.53
# Episode length: 1385.60 +/- 1323.04
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.39e+03  |
# |    mean_reward     | -1.47e+04 |
# | time/              |           |
# |    total_timesteps | 86000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 956       |
# |    ep_rew_mean     | -1.38e+03 |
# | time/              |           |
# |    fps             | 148       |
# |    iterations      | 21        |
# |    time_elapsed    | 579       |
# |    total_timesteps | 86016     |
# ----------------------------------
# Eval num_timesteps=87000, episode_reward=-5920.00 +/- 6146.78
# Episode length: 743.80 +/- 452.93
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 744          |
# |    mean_reward          | -5.92e+03    |
# | time/                   |              |
# |    total_timesteps      | 87000        |
# | train/                  |              |
# |    approx_kl            | 0.0021146757 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 10.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -5.89e-06    |
# |    value_loss           | 18.2         |
# ------------------------------------------
# Eval num_timesteps=88000, episode_reward=-13604.00 +/- 13596.87
# Episode length: 1324.60 +/- 1018.38
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.32e+03  |
# |    mean_reward     | -1.36e+04 |
# | time/              |           |
# |    total_timesteps | 88000     |
# ----------------------------------
# Eval num_timesteps=89000, episode_reward=-11280.00 +/- 12802.85
# Episode length: 1151.00 +/- 956.71
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.15e+03  |
# |    mean_reward     | -1.13e+04 |
# | time/              |           |
# |    total_timesteps | 89000     |
# ----------------------------------
# Eval num_timesteps=90000, episode_reward=-7775.00 +/- 9380.78
# Episode length: 884.80 +/- 699.84
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 885       |
# |    mean_reward     | -7.78e+03 |
# | time/              |           |
# |    total_timesteps | 90000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 976       |
# |    ep_rew_mean     | -1.59e+03 |
# | time/              |           |
# |    fps             | 148       |
# |    iterations      | 22        |
# |    time_elapsed    | 606       |
# |    total_timesteps | 90112     |
# ----------------------------------
# Eval num_timesteps=91000, episode_reward=-86.00 +/- 1928.84
# Episode length: 317.00 +/- 146.65
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 317         |
# |    mean_reward          | -86         |
# | time/                   |             |
# |    total_timesteps      | 91000       |
# | train/                  |             |
# |    approx_kl            | 0.004508433 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 9.1         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000184    |
# |    value_loss           | 21.6        |
# -----------------------------------------
# Eval num_timesteps=92000, episode_reward=-5375.00 +/- 8902.07
# Episode length: 709.80 +/- 663.63
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 710       |
# |    mean_reward     | -5.38e+03 |
# | time/              |           |
# |    total_timesteps | 92000     |
# ----------------------------------
# Eval num_timesteps=93000, episode_reward=119.00 +/- 1715.78
# Episode length: 298.20 +/- 127.26
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 298      |
# |    mean_reward     | 119      |
# | time/              |          |
# |    total_timesteps | 93000    |
# ---------------------------------
# Eval num_timesteps=94000, episode_reward=-1419.00 +/- 1803.30
# Episode length: 416.80 +/- 136.43
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 417       |
# |    mean_reward     | -1.42e+03 |
# | time/              |           |
# |    total_timesteps | 94000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 992       |
# |    ep_rew_mean     | -1.75e+03 |
# | time/              |           |
# |    fps             | 151       |
# |    iterations      | 23        |
# |    time_elapsed    | 621       |
# |    total_timesteps | 94208     |
# ----------------------------------
# Eval num_timesteps=95000, episode_reward=-5543.00 +/- 8926.29
# Episode length: 720.20 +/- 666.71
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 720         |
# |    mean_reward          | -5.54e+03   |
# | time/                   |             |
# |    total_timesteps      | 95000       |
# | train/                  |             |
# |    approx_kl            | 0.004770969 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.3         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 48.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000817   |
# |    value_loss           | 73.5        |
# -----------------------------------------
# Eval num_timesteps=96000, episode_reward=-4134.00 +/- 10242.21
# Episode length: 618.40 +/- 767.52
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 618       |
# |    mean_reward     | -4.13e+03 |
# | time/              |           |
# |    total_timesteps | 96000     |
# ----------------------------------
# Eval num_timesteps=97000, episode_reward=-2537.00 +/- 5712.60
# Episode length: 495.60 +/- 423.30
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 496       |
# |    mean_reward     | -2.54e+03 |
# | time/              |           |
# |    total_timesteps | 97000     |
# ----------------------------------
# Eval num_timesteps=98000, episode_reward=-6681.00 +/- 9477.95
# Episode length: 807.40 +/- 708.29
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 807       |
# |    mean_reward     | -6.68e+03 |
# | time/              |           |
# |    total_timesteps | 98000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.01e+03  |
# |    ep_rew_mean     | -1.95e+03 |
# | time/              |           |
# |    fps             | 153       |
# |    iterations      | 24        |
# |    time_elapsed    | 641       |
# |    total_timesteps | 98304     |
# ----------------------------------
# Eval num_timesteps=99000, episode_reward=-26049.00 +/- 9350.90
# Episode length: 2275.60 +/- 709.27
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2.28e+03     |
# |    mean_reward          | -2.6e+04     |
# | time/                   |              |
# |    total_timesteps      | 99000        |
# | train/                  |              |
# |    approx_kl            | 0.0025574109 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.712        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 18.6         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 6.66e-06     |
# |    value_loss           | 36           |
# ------------------------------------------
# Eval num_timesteps=100000, episode_reward=-6078.00 +/- 13922.51
# Episode length: 772.40 +/- 1056.16
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 772       |
# |    mean_reward     | -6.08e+03 |
# | time/              |           |
# |    total_timesteps | 100000    |
# ----------------------------------
# Eval num_timesteps=101000, episode_reward=-7952.00 +/- 15797.89
# Episode length: 908.60 +/- 1190.66
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 909       |
# |    mean_reward     | -7.95e+03 |
# | time/              |           |
# |    total_timesteps | 101000    |
# ----------------------------------
# Eval num_timesteps=102000, episode_reward=-15280.00 +/- 16482.07
# Episode length: 1462.60 +/- 1241.72
# ----------------------------------
# | eval/              |           |
# |    mean_ep_length  | 1.46e+03  |
# |    mean_reward     | -1.53e+04 |
# | time/              |           |
# |    total_timesteps | 102000    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -2e+03   |
# | time/              |          |
# |    fps             | 151      |
# |    iterations      | 25       |
# |    time_elapsed    | 675      |
# |    total_timesteps | 102400   |
# ---------------------------------
# Final model saved to ./logs/ppo_rs4_finetune_model/final_model

# %%
# Start TensorBoard to monitor logs
# %tensorboard --logdir ./logs/ppo_rs3_finetune_model --port=5005

# %% [markdown]
# ### Test Model 6

# %%
# Load the best baseline model
log_dir = "./logs/ppo_rs3_finetune_model/"
model_path = log_dir + 'best_model/best_model.zip'
model = PPO.load(model_path)

# Create test environment
env_test = env_gym.TrafficEnvironment()

# %%
# Test the model
num_episodes = 1000
file_name = 'ppo_rs3_finetune_model_test_log.json'
rewards, timesteps = util.test_model(model=model, env=env_test, num_episodes=num_episodes, output_file=file_name)

# %% [markdown]
# ### Analysis of Model 6

# %%
util.plot_test_results(rewards=rewards, timesteps=timesteps, interval=100)
# Out:
# Average reward of 1000 episodes is -11486.
# Average timesteps of 1000 episodes is 1037.

# %%
file_name = 'ppo_rs3_finetune_model_test_log.json'
util.plot_test_boxplots(json_file=file_name)

# %%
util.calculate_action_percentages(log_file=file_name)
print("")
util.calculate_clearance_rate_percentages(log_file=file_name)
# Out:
# Total actions across 1000 episodes: 1036509
# Action -1: 0.2%
# Action 0: 0.0%
# Action 1: 99.8%
#
# Total timesteps across 1000 episodes (including initial states): 1037509
# Lane 1:
#   77.2% of timesteps had a clearance rate less than 5
#   87.5% of timesteps had a clearance rate less than 10
# Lane 2:
#   76.8% of timesteps had a clearance rate less than 5
#   87.4% of timesteps had a clearance rate less than 10
# Lane 3:
#   76.7% of timesteps had a clearance rate less than 5
#   87.4% of timesteps had a clearance rate less than 10
# Lane 4:
#   76.8% of timesteps had a clearance rate less than 5
#   87.7% of timesteps had a clearance rate less than 10
# Lane 5:
#   77.2% of timesteps had a clearance rate less than 5
#   88.0% of timesteps had a clearance rate less than 10
